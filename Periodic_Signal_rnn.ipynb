# %%
from __future__ import print_function
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

# %% [markdown]
# ## Generate Periodic Signal

# %% [markdown]
# #### 1. Generate with specified latent dynamic model (nonlinear everywhere)

# %%
# Nonlinear functions (Input can be arrays)
def sigmoid(x):
    return 1 / (1 + math.exp(-x))


def sq(x):
    return x ** 2


def sqrtplus(x):
    sgn = np.sign(x)
    y = np.multiply(sgn, np.sqrt(np.absolute(x)))
    return y


def const_zero(x):
    return np.zeros(len(x))

def twosin2_point1(x):
    return 2 * np.sin(2*x) - 0.1

# %%
class TwoFuncSamp():
    def __init__(self, n_obs, obs_dim, fh1, fh2, fob1, fob2, coef_fh1, coef_fh2, coef_fob1, coef_fob2):
        
        self.h_dim = 2
        self.fh1 = fh1
        self.fh2 = fh2
        self.fob1 = fob1
        self.fob2 = fob2
        self.coef_fh1 = coef_fh1
        self.coef_fh2 = coef_fh2
        self.coef_fob1 = coef_fob1
        self.coef_fob2 = coef_fob2
        
        # Initial state multivariate normal with mean = 0.1 and covariance matrix = Diag(2)
        self.obs_dim = obs_dim
        self.n_obs = n_obs
        self.h_dim = 2
        self.initial_mean = np.array([0, 0.5])
        self.initial_log_diag_sq = np.log(np.array([1, 1.1]))

        
        # Dimension transformation from latent to observation
        self.emit_mat = np.random.uniform(0.95, 1.05, self.h_dim).reshape(self.h_dim, 1)
        
    
    def sample_all(self, n_timesteps, random_seed = None):
        mus = np.zeros([n_timesteps, self.h_dim])
        log_diag_sigmas = np.zeros([n_timesteps, self.h_dim])
        observations = np.zeros([n_timesteps, self.n_obs, self.obs_dim])
        
        if random_seed is not None:
            np.random.seed(random_seed)

        # Initialize hidden mean and diagonal entries of covariance matrix (with small Gaussian noise)
        mus[0, :] = self.coef_fh1 * self.fh1(self.initial_mean) + self.coef_fh2 * self.fh2(self.initial_mean) + 0.1 * np.random.normal(0, 1, self.h_dim)
        log_diag_sigmas[0, :] = self.coef_fh1 * self.fh1(self.initial_log_diag_sq) + self.coef_fh2 * self.fh2(self.initial_log_diag_sq) + 0.1 * np.random.normal(0, 1, self.h_dim)
        
        # Initialize observation (Latent is Gaussian, linear transform to modify dimension)
        for j in range(self.n_obs):
            samp_h = np.random.multivariate_normal(mus[0, :], np.diag(np.exp(log_diag_sigmas[0, :])), self.obs_dim)
            pre_samp_obs = np.dot(samp_h, self.emit_mat)
            temp = self.coef_fob1 * self.fob1(pre_samp_obs) + self.coef_fob2 * self.fob2(pre_samp_obs)
            temp = temp.flatten()
            observations[0, j, :] = temp + np.random.normal(0, 1, self.obs_dim)
        
        for i in range(1, n_timesteps):
            # Update hidden mean and diagonal entries of covariance matrix at time step i (with small Gaussian noise)
            mus[i, :] = self.coef_fh1 * self.fh1(mus[i - 1, :]) + self.coef_fh2 * self.fh2(mus[i - 1, :]) + 0.1 * np.random.normal(0, 1, self.h_dim)
            log_diag_sigmas[i, :] = self.coef_fh1 * self.fh1(log_diag_sigmas[i - 1, :]) + self.coef_fh2 * self.fh2(log_diag_sigmas[i - 1, :]) + 0.1 * np.random.normal(0, 1, self.h_dim)
            
            # Generate a series of observation vectors
            for j in range(self.n_obs):
                samp_h = np.random.multivariate_normal(mus[i, :], np.diag(np.exp(log_diag_sigmas[i, :])), self.obs_dim)
                pre_samp_obs = np.dot(samp_h, self.emit_mat)
                temp = self.coef_fob1 * self.fob1(pre_samp_obs) + self.coef_fob2 * self.fob2(pre_samp_obs)
                temp = temp.flatten()
                observations[i, j, :] = temp + np.random.normal(0, 1, self.obs_dim)
        return mus, log_diag_sigmas, observations

# %%
# Sampler following Professor's suggestion
class PeriodicSamp():
    def __init__(self, n_obs, obs_dim, f_hidden, coef_fh):
        self.h_dim = 2
        self.obs_dim = obs_dim
        self.fh = f_hidden
        self.coef_fh = coef_fh
        
        # Initial state multivariate normal with mean = 0.1 and covariance matrix = Diag(2)
        self.n_obs = n_obs
        self.initial_state = np.random.multivariate_normal(np.zeros(self.h_dim), np.eye(self.h_dim), self.n_obs)

        # We do not focus on VAE, therefore the emission function is linear and should be easy to learn.
        self.emission_mat = np.random.uniform(0.95, 1.05, self.h_dim * self.obs_dim).reshape(self.obs_dim, self.h_dim)
        
    
    def sample_all(self, n_timesteps, random_seed = None):
        latents = np.zeros([n_timesteps, self.n_obs, self.h_dim])
        observations = np.zeros([n_timesteps, self.n_obs, self.obs_dim])
        
        if random_seed is not None:
            np.random.seed(random_seed)

        for i in range(self.n_obs):
          diag_h = np.random.uniform(1, 5, self.h_dim)
          diag_o = np.random.uniform(1, 5, self.obs_dim)

          # Hidden state is multivariate Gaussian plus iid Gaussian noise
          latents[0, i, :] = np.random.multivariate_normal(self.coef_fh * self.fh(self.initial_state[i]), 0.01 * np.diag(diag_h))
          # Initialize observation (linear transformation + Gaussian noise)
          observations[0, i, :] = np.matmul(self.emission_mat, latents[0, i, :]) + 0.1 * np.random.multivariate_normal(np.zeros(self.obs_dim), np.diag(diag_o))   
        
        for t in range(1, n_timesteps):
            for i in range(self.n_obs):
              diag_h = np.random.uniform(1, 5, self.h_dim)
              diag_o = np.random.uniform(1, 5, self.obs_dim)
              # Hidden state is multivariate Gaussian plus iid Gaussian noise
              latents[t, i, :] = np.random.multivariate_normal(self.coef_fh * self.fh(latents[t - 1, i, :]), 0.01 * np.diag(diag_h))
              # Initialize observation (linear transformation + Gaussian noise)
              observations[t, i, :] = np.matmul(self.emission_mat, latents[t, i, :]) + 0.1 * np.random.multivariate_normal(np.zeros(self.obs_dim), np.diag(diag_o))
        return latents, observations

# %%
h_dim = 2
obs_dim = 50
n_obs = 10000
n_timestep = 10

sampler2 = PeriodicSamp(n_obs, obs_dim, np.cos, 2)

# %%
latents, obs = sampler2.sample_all(n_timestep)

# %%
print(obs.shape)
# Out:
# (10, 10000, 50)

# %%
obs = np.transpose(obs, (1, 0, 2))
print(obs.shape)
# Out:
# (10000, 10, 50)

# %%
# Plot the temporal trend for each dimension of first five observations
x1 = np.arange(n_timestep)
for n in range(10):
    for i in range(sampler2.obs_dim):
        plt.plot(x1, obs[n, :, i], marker = 'o', markersize = 4)

    plt.xlabel('Time')
    plt.ylabel('Magnitude')
    plt.title('Each dimension of observation '+ str(n + 1));
    plt.show()

# %%
X_range = np.arange(0, 9)
Y_range = np.arange(1, 10)
X = obs[:, X_range, :]
Y = obs[:, Y_range, :]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (10000, 9, 50)
# (10000, 9, 50)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (8000, 9, 50) (8000, 9, 50) (2000, 9, 50) (2000, 9, 50)

# %%
train_X_small = X_train[0: 5]
test_X_small = X_test[0: 2]
train_Y_small = Y_train[0: 5]
test_Y_small = Y_test[0: 2]

# %% [markdown]
# ## Prepare Dataset

# %%
batch_size = 16
seed = 1
epochs = 400
cuda = True
log_interval = 10
h_d = 16
l_d = 8
sample_size=10


device = torch.device("cuda" if cuda else "cpu")

kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}

"""

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)



test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)

"""
# Out:
# "\n\ntrain_loader = torch.utils.data.DataLoader(\n    datasets.MNIST('./data', train=True, download=True,\n                   transform=transforms.ToTensor()),\n    batch_size=batch_size, shuffle=True, **kwargs)\n\n\n\ntest_loader = torch.utils.data.DataLoader(\n    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),\n    batch_size=batch_size, shuffle=True, **kwargs)\n\n"

# %% [markdown]
# #### Dataset Object

# %%
class SignalData():
    def __init__(self, train_obs, train_tar, test_obs, test_tar, test = False, transform = None):
        self.test = test
        self.transform = transform

        if (self.test == False):
          self.obs = torch.from_numpy(train_obs).float()
          self.targets = torch.from_numpy(train_tar).float()

        else:      
          self.obs = test_obs
          self.targets = test_tar

    def __len__(self):
        return len(self.obs)
    
    def __getitem__(self, index):
        if self.transform is not None:
            ob = self.transform(self.obs[index])
            tar = self.transform(self.targets[index])
        else:
            ob = self.obs[index]
            tar = self.targets[index]
        return ob, tar

# %% [markdown]
# ### Create Dataloader

# %%
train_set = SignalData(X_train, Y_train, X_test, Y_test, test = False, transform = None)
test_set = SignalData(X_train, Y_train, X_test, Y_test, test = True, transform = None)

# %%
train_set_small = SignalData(train_X_small, train_Y_small, test_X_small, test_Y_small, test = False, transform = None)
test_set_small = SignalData(train_X_small, train_Y_small, test_X_small, test_Y_small, test = True, transform = None)

# %%
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle = True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle = False, **kwargs)

# %%
train_loader_small = torch.utils.data.DataLoader(train_set_small, batch_size=1, shuffle = True, **kwargs)
test_loader_small = torch.utils.data.DataLoader(test_set_small, batch_size=1, shuffle = False, **kwargs)

# %% [markdown]
# ### Model Definition

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        # Encoder
        self.fc1 = nn.Linear(50, h_d)
        self.fc21 = nn.Linear(h_d, l_d)
        self.fc22 = nn.Linear(h_d, l_d)
        
        #transition layer
        input_dim = l_d
        self.rnn_mu = nn.RNN(input_size=input_dim,hidden_size=l_d,batch_first=True)
        self.rnn_sigma = nn.RNN(input_size=input_dim,hidden_size=l_d,batch_first=True)
        
        # Decoder should also be a probability distribution
        self.fc3 = nn.Linear(l_d, h_d)
        self.fc4 = nn.Linear(h_d, 50)
        self.fc5 = nn.Linear(h_d, 50)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize1(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std
    
    def transition(self, z):
        mu2,_ = self.rnn_mu(z)
        logvar2,_ = self.rnn_sigma(z)
        return mu2,logvar2
    
    def reparameterize2(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = torch.tanh(self.fc3(z))
        return self.fc4(h3), self.fc5(h3)

    def forward(self, x):
        mu1, logvar1 = self.encode(x.view(-1,50))
        #z1 = self.reparameterize1(mu1, logvar1)
        #mu2, logvar2 = self.transition(z1)
        #z2 = self.reparameterize2(mu2, logvar2)
        
        mu = torch.empty(sample_size, x.shape[0], x.shape[1], l_d , dtype=torch.float).to(device)
        logvar = torch.empty(sample_size, x.shape[0], x.shape[1], l_d , dtype=torch.float).to(device)
        for i in range(sample_size):
            z1 = self.reparameterize1(mu1, logvar1)
            z1 = z1.reshape(-1,9,l_d)
            mu2, logvar2 = self.transition(z1)
            mu[i] = mu2
            logvar[i] = logvar2
        z2 = self.reparameterize2(mu[0], logvar[0])
        
        mu_obs, logvar_obs = self.decode(z2)
        
        return mu_obs, logvar_obs, mu, logvar

# %%
model = VAE().to(device)
#adam optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(x, mu_obs, logvar_obs, mu, logvar):
    covar = torch.diag_embed(torch.exp(logvar_obs))
    n = torch.distributions.MultivariateNormal(mu_obs, covariance_matrix = covar)
    neg_llh = torch.sum(-n.log_prob(x))

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar[0,:,0,:] - mu[0,:,0,:].pow(2) - logvar[0,:,0,:].exp())
    EKLD = 0
    for i in range(1,9):        
        tmp = -0.5 * torch.sum(1 + logvar[:,:,i,:] - mu[:,:,i,:].pow(2) - logvar[:,:,i,:].exp())/sample_size
        EKLD += tmp
    

    return neg_llh + KLD + EKLD

# %% [markdown]
# ### Define training and testing algorithm

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (obs, target) in enumerate(train_loader):
        obs = obs.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        mu_obs, logvar_obs, mu, logvar = model(obs.float())
        loss = loss_function(target.float(), mu_obs, logvar_obs, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        #if batch_idx % log_interval == 0:
         #   print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
          #      epoch, batch_idx * len(img), len(train_loader.dataset),
           #     100. * batch_idx / len(train_loader),
            #    loss.item() / len(img)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))
    return train_loss

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (obs, target) in enumerate(test_loader):
            obs = obs.to(device)
            target = target.to(device)
            mu_obs, logvar_obs, mu, logvar = model(obs.float())
            test_loss += loss_function(target.float(), mu_obs, logvar_obs, mu, logvar).item()
    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))
    return test_loss

# %% [markdown]
# ### Run Training

# %%
train_losses = []
test_losses = []
for epoch in range(1, epochs + 1):
    train_loss = train(epoch)
    test_loss = test(epoch)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
# Out:
# ====> Epoch: 1 Average loss: 801.6793
# ====> Test set loss: 672.2338
# ====> Epoch: 2 Average loss: 655.1389
# ====> Test set loss: 626.6286
# ====> Epoch: 3 Average loss: 606.8701
# ====> Test set loss: 589.7228
# ====> Epoch: 4 Average loss: 583.6255
# ====> Test set loss: 571.5206
# ====> Epoch: 5 Average loss: 569.1779
# ====> Test set loss: 574.4489
# ====> Epoch: 6 Average loss: 556.5007
# ====> Test set loss: 548.5270
# ====> Epoch: 7 Average loss: 548.1427
# ====> Test set loss: 537.7355
# ====> Epoch: 8 Average loss: 537.9530
# ====> Test set loss: 532.4425
# ====> Epoch: 9 Average loss: 534.2265
# ====> Test set loss: 533.8434
# ====> Epoch: 10 Average loss: 529.3688
# ====> Test set loss: 524.4424
# ====> Epoch: 11 Average loss: 523.3205
# ====> Test set loss: 519.9254
# ====> Epoch: 12 Average loss: 522.8028
# ====> Test set loss: 519.6457
# ====> Epoch: 13 Average loss: 518.1994
# ====> Test set loss: 512.7637
# ====> Epoch: 14 Average loss: 515.0150
# ====> Test set loss: 511.2537
# ====> Epoch: 15 Average loss: 512.8083
# ====> Test set loss: 506.9758
# ====> Epoch: 16 Average loss: 510.4617
# ====> Test set loss: 508.6581
# ====> Epoch: 17 Average loss: 509.1574
# ====> Test set loss: 504.7485
# ====> Epoch: 18 Average loss: 505.9697
# ====> Test set loss: 510.9547
# ====> Epoch: 19 Average loss: 504.1503
# ====> Test set loss: 502.1263
# ====> Epoch: 20 Average loss: 501.8566
# ====> Test set loss: 522.2940
# ====> Epoch: 21 Average loss: 500.0208
# ====> Test set loss: 501.3693
# ====> Epoch: 22 Average loss: 497.2970
# ====> Test set loss: 495.7615
# ====> Epoch: 23 Average loss: 497.0753
# ====> Test set loss: 490.6096
# ====> Epoch: 24 Average loss: 492.6520
# ====> Test set loss: 492.4173
# ====> Epoch: 25 Average loss: 491.8275
# ====> Test set loss: 489.0804
# ====> Epoch: 26 Average loss: 489.3489
# ====> Test set loss: 498.4212
# ====> Epoch: 27 Average loss: 487.1699
# ====> Test set loss: 487.4192
# ====> Epoch: 28 Average loss: 486.0310
# ====> Test set loss: 481.8279
# ====> Epoch: 29 Average loss: 485.3784
# ====> Test set loss: 481.1976
# ====> Epoch: 30 Average loss: 484.5184
# ====> Test set loss: 490.5659
# ====> Epoch: 31 Average loss: 482.4923
# ====> Test set loss: 481.9029
# ====> Epoch: 32 Average loss: 480.3306
# ====> Test set loss: 477.4651
# ====> Epoch: 33 Average loss: 478.8425
# ====> Test set loss: 504.3193
# ====> Epoch: 34 Average loss: 479.6835
# ====> Test set loss: 477.1432
# ====> Epoch: 35 Average loss: 478.0979
# ====> Test set loss: 481.4486
# ====> Epoch: 36 Average loss: 478.3317
# ====> Test set loss: 474.9027
# ====> Epoch: 37 Average loss: 479.5244
# ====> Test set loss: 473.9586
# ====> Epoch: 38 Average loss: 477.6994
# ====> Test set loss: 478.6743
# ====> Epoch: 39 Average loss: 474.1996
# ====> Test set loss: 473.5867
# ====> Epoch: 40 Average loss: 474.4740
# ====> Test set loss: 470.1928
# ====> Epoch: 41 Average loss: 472.7780
# ====> Test set loss: 472.4088
# ====> Epoch: 42 Average loss: 473.0077
# ====> Test set loss: 469.2801
# ====> Epoch: 43 Average loss: 473.7855
# ====> Test set loss: 472.8821
# ====> Epoch: 44 Average loss: 472.2104
# ====> Test set loss: 472.8076
# ====> Epoch: 45 Average loss: 473.6700
# ====> Test set loss: 467.9451
# ====> Epoch: 46 Average loss: 470.1442
# ====> Test set loss: 478.8588
# ====> Epoch: 47 Average loss: 466.6816
# ====> Test set loss: 465.5832
# ====> Epoch: 48 Average loss: 468.8406
# ====> Test set loss: 485.0861
# ====> Epoch: 49 Average loss: 467.9569
# ====> Test set loss: 469.6775
# ====> Epoch: 50 Average loss: 465.2835
# ====> Test set loss: 466.6141
# ====> Epoch: 51 Average loss: 464.1522
# ====> Test set loss: 463.0487
# ====> Epoch: 52 Average loss: 464.1860
# ====> Test set loss: 473.1134
# ====> Epoch: 53 Average loss: 466.7344
# ====> Test set loss: 470.6173
# ====> Epoch: 54 Average loss: 465.2865
# ====> Test set loss: 466.6737
# ====> Epoch: 55 Average loss: 464.6528
# ====> Test set loss: 463.2202
# ====> Epoch: 56 Average loss: 463.5564
# ====> Test set loss: 460.3035
# ====> Epoch: 57 Average loss: 465.4582
# ====> Test set loss: 462.3210
# ====> Epoch: 58 Average loss: 462.5453
# ====> Test set loss: 457.8592
# ====> Epoch: 59 Average loss: 461.1760
# ====> Test set loss: 460.6066
# ====> Epoch: 60 Average loss: 463.2533
# ====> Test set loss: 457.9076
# ====> Epoch: 61 Average loss: 462.3579
# ====> Test set loss: 463.4035
# ====> Epoch: 62 Average loss: 460.4589
# ====> Test set loss: 466.3188
# ====> Epoch: 63 Average loss: 462.9564
# ====> Test set loss: 463.6903
# ====> Epoch: 64 Average loss: 460.3466
# ====> Test set loss: 467.2145
# ====> Epoch: 65 Average loss: 461.1240
# ====> Test set loss: 463.6580
# ====> Epoch: 66 Average loss: 461.6769
# ====> Test set loss: 469.3653
# ====> Epoch: 67 Average loss: 463.0013
# ====> Test set loss: 461.6268
# ====> Epoch: 68 Average loss: 460.9308
# ====> Test set loss: 461.7937
# ====> Epoch: 69 Average loss: 461.6352
# ====> Test set loss: 458.0454
# ====> Epoch: 70 Average loss: 458.8003
# ====> Test set loss: 458.9901
# ====> Epoch: 71 Average loss: 461.3230
# ====> Test set loss: 457.0662
# ====> Epoch: 72 Average loss: 461.6841
# ====> Test set loss: 460.0783
# ====> Epoch: 73 Average loss: 459.8605
# ====> Test set loss: 461.3991
# ====> Epoch: 74 Average loss: 460.5951
# ====> Test set loss: 470.5077
# ====> Epoch: 75 Average loss: 460.4254
# ====> Test set loss: 459.3307
# ====> Epoch: 76 Average loss: 460.9377
# ====> Test set loss: 458.1868
# ====> Epoch: 77 Average loss: 460.6054
# ====> Test set loss: 458.4473
# ====> Epoch: 78 Average loss: 461.2804
# ====> Test set loss: 457.0614
# ====> Epoch: 79 Average loss: 458.6692
# ====> Test set loss: 461.1675
# ====> Epoch: 80 Average loss: 458.4079
# ====> Test set loss: 459.2441
# ====> Epoch: 81 Average loss: 459.6396
# ====> Test set loss: 458.7283
# ====> Epoch: 82 Average loss: 457.8936
# ====> Test set loss: 459.7679
# ====> Epoch: 83 Average loss: 458.0811
# ====> Test set loss: 460.2502
# ====> Epoch: 84 Average loss: 458.3509
# ====> Test set loss: 460.3498
# ====> Epoch: 85 Average loss: 459.5087
# ====> Test set loss: 458.5019
# ====> Epoch: 86 Average loss: 459.5449
# ====> Test set loss: 466.6070
# ====> Epoch: 87 Average loss: 460.5843
# ====> Test set loss: 462.4311
# ====> Epoch: 88 Average loss: 459.6111
# ====> Test set loss: 460.8049
# ====> Epoch: 89 Average loss: 456.8639
# ====> Test set loss: 456.0651
# ====> Epoch: 90 Average loss: 456.8874
# ====> Test set loss: 456.2349
# ====> Epoch: 91 Average loss: 458.8126
# ====> Test set loss: 466.9429
# ====> Epoch: 92 Average loss: 456.8656
# ====> Test set loss: 459.6724
# ====> Epoch: 93 Average loss: 458.6757
# ====> Test set loss: 454.0752
# ====> Epoch: 94 Average loss: 456.1943
# ====> Test set loss: 459.2265
# ====> Epoch: 95 Average loss: 458.4977
# ====> Test set loss: 459.0760
# ====> Epoch: 96 Average loss: 459.8065
# ====> Test set loss: 456.4772
# ====> Epoch: 97 Average loss: 456.7993
# ====> Test set loss: 459.2451
# ====> Epoch: 98 Average loss: 456.5275
# ====> Test set loss: 457.2093
# ====> Epoch: 99 Average loss: 457.1128
# ====> Test set loss: 454.8544
# ====> Epoch: 100 Average loss: 459.9149
# ====> Test set loss: 458.6545
# ====> Epoch: 101 Average loss: 457.4130
# ====> Test set loss: 456.0017
# ====> Epoch: 102 Average loss: 457.3581
# ====> Test set loss: 469.4211
# ====> Epoch: 103 Average loss: 458.0691
# ====> Test set loss: 470.6339
# ====> Epoch: 104 Average loss: 457.9174
# ====> Test set loss: 459.4606
# ====> Epoch: 105 Average loss: 457.1738
# ====> Test set loss: 456.7337
# ====> Epoch: 106 Average loss: 456.4352
# ====> Test set loss: 458.2404
# ====> Epoch: 107 Average loss: 456.0435
# ====> Test set loss: 458.7141
# ====> Epoch: 108 Average loss: 457.2080
# ====> Test set loss: 463.9916
# ====> Epoch: 109 Average loss: 455.7206
# ====> Test set loss: 456.4190
# ====> Epoch: 110 Average loss: 456.6428
# ====> Test set loss: 461.9672
# ====> Epoch: 111 Average loss: 455.4640
# ====> Test set loss: 454.6240
# ====> Epoch: 112 Average loss: 457.2612
# ====> Test set loss: 477.1875
# ====> Epoch: 113 Average loss: 456.3430
# ====> Test set loss: 463.7753
# ====> Epoch: 114 Average loss: 455.8595
# ====> Test set loss: 465.6828
# ====> Epoch: 115 Average loss: 454.4797
# ====> Test set loss: 457.1904
# ====> Epoch: 116 Average loss: 454.3006
# ====> Test set loss: 455.4159
# ====> Epoch: 117 Average loss: 456.6581
# ====> Test set loss: 452.9183
# ====> Epoch: 118 Average loss: 456.9604
# ====> Test set loss: 454.8252
# ====> Epoch: 119 Average loss: 455.1243
# ====> Test set loss: 458.1522
# ====> Epoch: 120 Average loss: 457.5915
# ====> Test set loss: 457.0025
# ====> Epoch: 121 Average loss: 454.5034
# ====> Test set loss: 457.3570
# ====> Epoch: 122 Average loss: 454.7610
# ====> Test set loss: 454.7892
# ====> Epoch: 123 Average loss: 455.7314
# ====> Test set loss: 453.7923
# ====> Epoch: 124 Average loss: 455.1262
# ====> Test set loss: 463.5515
# ====> Epoch: 125 Average loss: 454.3294
# ====> Test set loss: 456.3911
# ====> Epoch: 126 Average loss: 456.2738
# ====> Test set loss: 461.9574
# ====> Epoch: 127 Average loss: 454.8897
# ====> Test set loss: 456.9118
# ====> Epoch: 128 Average loss: 454.0113
# ====> Test set loss: 453.8786
# ====> Epoch: 129 Average loss: 455.3403
# ====> Test set loss: 456.6088
# ====> Epoch: 130 Average loss: 455.0774
# ====> Test set loss: 457.4458
# ====> Epoch: 131 Average loss: 453.6211
# ====> Test set loss: 465.4911
# ====> Epoch: 132 Average loss: 453.3819
# ====> Test set loss: 455.9199
# ====> Epoch: 133 Average loss: 452.0468
# ====> Test set loss: 456.1743
# ====> Epoch: 134 Average loss: 455.2463
# ====> Test set loss: 460.8742
# ====> Epoch: 135 Average loss: 453.8680
# ====> Test set loss: 454.1779
# ====> Epoch: 136 Average loss: 453.9132
# ====> Test set loss: 457.5181
# ====> Epoch: 137 Average loss: 454.0474
# ====> Test set loss: 453.9114
# ====> Epoch: 138 Average loss: 454.1458
# ====> Test set loss: 457.5281
# ====> Epoch: 139 Average loss: 454.1491
# ====> Test set loss: 458.1462
# ====> Epoch: 140 Average loss: 455.7351
# ====> Test set loss: 455.5860
# ====> Epoch: 141 Average loss: 453.1555
# ====> Test set loss: 454.6900
# ====> Epoch: 142 Average loss: 455.8764
# ====> Test set loss: 461.4704
# ====> Epoch: 143 Average loss: 453.9438
# ====> Test set loss: 456.3411
# ====> Epoch: 144 Average loss: 453.9427
# ====> Test set loss: 456.1838
# ====> Epoch: 145 Average loss: 453.1506
# ====> Test set loss: 451.3666
# ====> Epoch: 146 Average loss: 454.9031
# ====> Test set loss: 456.6291
# ====> Epoch: 147 Average loss: 454.5365
# ====> Test set loss: 452.2088
# ====> Epoch: 148 Average loss: 454.7449
# ====> Test set loss: 455.1325
# ====> Epoch: 149 Average loss: 452.4119
# ====> Test set loss: 456.9853
# ====> Epoch: 150 Average loss: 454.5989
# ====> Test set loss: 454.2573
# ====> Epoch: 151 Average loss: 454.2904
# ====> Test set loss: 466.6010
# ====> Epoch: 152 Average loss: 453.8166
# ====> Test set loss: 464.9928
# ====> Epoch: 153 Average loss: 451.5377
# ====> Test set loss: 462.1838
# ====> Epoch: 154 Average loss: 453.2170
# ====> Test set loss: 452.6416
# ====> Epoch: 155 Average loss: 451.5144
# ====> Test set loss: 459.9018
# ====> Epoch: 156 Average loss: 454.6604
# ====> Test set loss: 458.1078
# ====> Epoch: 157 Average loss: 451.7826
# ====> Test set loss: 461.2590
# ====> Epoch: 158 Average loss: 452.3355
# ====> Test set loss: 454.4711
# ====> Epoch: 159 Average loss: 451.8576
# ====> Test set loss: 454.6793
# ====> Epoch: 160 Average loss: 452.5474
# ====> Test set loss: 460.0164
# ====> Epoch: 161 Average loss: 454.1045
# ====> Test set loss: 453.4146
# ====> Epoch: 162 Average loss: 452.5258
# ====> Test set loss: 454.8715
# ====> Epoch: 163 Average loss: 451.5409
# ====> Test set loss: 472.3445
# ====> Epoch: 164 Average loss: 452.8993
# ====> Test set loss: 454.2467
# ====> Epoch: 165 Average loss: 452.6551
# ====> Test set loss: 456.5311
# ====> Epoch: 166 Average loss: 453.5022
# ====> Test set loss: 455.1269
# ====> Epoch: 167 Average loss: 451.2681
# ====> Test set loss: 455.1246
# ====> Epoch: 168 Average loss: 452.4333
# ====> Test set loss: 455.3860
# ====> Epoch: 169 Average loss: 452.5565
# ====> Test set loss: 455.2433
# ====> Epoch: 170 Average loss: 454.4760
# ====> Test set loss: 452.9150
# ====> Epoch: 171 Average loss: 452.1562
# ====> Test set loss: 456.3020
# ====> Epoch: 172 Average loss: 451.6051
# ====> Test set loss: 455.2110
# ====> Epoch: 173 Average loss: 453.0014
# ====> Test set loss: 454.8726
# ====> Epoch: 174 Average loss: 452.2188
# ====> Test set loss: 452.5327
# ====> Epoch: 175 Average loss: 453.7799
# ====> Test set loss: 453.1196
# ====> Epoch: 176 Average loss: 451.4187
# ====> Test set loss: 451.8618
# ====> Epoch: 177 Average loss: 454.6044
# ====> Test set loss: 455.0453
# ====> Epoch: 178 Average loss: 451.2679
# ====> Test set loss: 452.7882
# ====> Epoch: 179 Average loss: 452.6788
# ====> Test set loss: 450.2499
# ====> Epoch: 180 Average loss: 452.4518
# ====> Test set loss: 449.6077
# ====> Epoch: 181 Average loss: 452.5939
# ====> Test set loss: 455.9226
# ====> Epoch: 182 Average loss: 450.4164
# ====> Test set loss: 451.1488
# ====> Epoch: 183 Average loss: 453.7827
# ====> Test set loss: 451.6329
# ====> Epoch: 184 Average loss: 450.9899
# ====> Test set loss: 451.4215
# ====> Epoch: 185 Average loss: 451.8719
# ====> Test set loss: 453.1834
# ====> Epoch: 186 Average loss: 450.8237
# ====> Test set loss: 450.5093
# ====> Epoch: 187 Average loss: 451.5690
# ====> Test set loss: 454.4851
# ====> Epoch: 188 Average loss: 452.0657
# ====> Test set loss: 453.7712
# ====> Epoch: 189 Average loss: 450.6689
# ====> Test set loss: 451.4216
# ====> Epoch: 190 Average loss: 453.1978
# ====> Test set loss: 452.2382
# ====> Epoch: 191 Average loss: 451.7967
# ====> Test set loss: 455.0723
# ====> Epoch: 192 Average loss: 451.6761
# ====> Test set loss: 454.3885
# ====> Epoch: 193 Average loss: 451.7921
# ====> Test set loss: 452.7553
# ====> Epoch: 194 Average loss: 450.0752
# ====> Test set loss: 456.4071
# ====> Epoch: 195 Average loss: 450.3612
# ====> Test set loss: 454.0684
# ====> Epoch: 196 Average loss: 451.9592
# ====> Test set loss: 455.0768
# ====> Epoch: 197 Average loss: 451.1926
# ====> Test set loss: 451.4355
# ====> Epoch: 198 Average loss: 451.6858
# ====> Test set loss: 452.3898
# ====> Epoch: 199 Average loss: 452.1131
# ====> Test set loss: 457.6016
# ====> Epoch: 200 Average loss: 451.4956
# ====> Test set loss: 453.0854
# ====> Epoch: 201 Average loss: 451.4352
# ====> Test set loss: 453.1828
# ====> Epoch: 202 Average loss: 450.0389
# ====> Test set loss: 457.2213
# ====> Epoch: 203 Average loss: 450.7984
# ====> Test set loss: 453.5061
# ====> Epoch: 204 Average loss: 448.9660
# ====> Test set loss: 450.9539
# ====> Epoch: 205 Average loss: 451.0907
# ====> Test set loss: 469.0728
# ====> Epoch: 206 Average loss: 451.6426
# ====> Test set loss: 451.5144
# ====> Epoch: 207 Average loss: 449.2646
# ====> Test set loss: 452.0872
# ====> Epoch: 208 Average loss: 450.3993
# ====> Test set loss: 451.9586
# ====> Epoch: 209 Average loss: 450.4996
# ====> Test set loss: 450.9597
# ====> Epoch: 210 Average loss: 451.0096
# ====> Test set loss: 453.8211
# ====> Epoch: 211 Average loss: 450.5361
# ====> Test set loss: 460.2849
# ====> Epoch: 212 Average loss: 449.7588
# ====> Test set loss: 459.9506
# ====> Epoch: 213 Average loss: 451.4608
# ====> Test set loss: 453.1124
# ====> Epoch: 214 Average loss: 451.9032
# ====> Test set loss: 456.0027
# ====> Epoch: 215 Average loss: 452.6039
# ====> Test set loss: 457.9565
# ====> Epoch: 216 Average loss: 449.8017
# ====> Test set loss: 452.0305
# ====> Epoch: 217 Average loss: 451.0511
# ====> Test set loss: 452.6882
# ====> Epoch: 218 Average loss: 450.2681
# ====> Test set loss: 458.5334
# ====> Epoch: 219 Average loss: 451.7680
# ====> Test set loss: 465.2852
# ====> Epoch: 220 Average loss: 448.2620
# ====> Test set loss: 457.0869
# ====> Epoch: 221 Average loss: 450.7791
# ====> Test set loss: 452.0739
# ====> Epoch: 222 Average loss: 451.5412
# ====> Test set loss: 451.8104
# ====> Epoch: 223 Average loss: 450.8477
# ====> Test set loss: 453.7682
# ====> Epoch: 224 Average loss: 450.0669
# ====> Test set loss: 457.5243
# ====> Epoch: 225 Average loss: 450.8777
# ====> Test set loss: 462.5250
# ====> Epoch: 226 Average loss: 450.0298
# ====> Test set loss: 460.6196
# ====> Epoch: 227 Average loss: 448.9183
# ====> Test set loss: 458.2273
# ====> Epoch: 228 Average loss: 450.1394
# ====> Test set loss: 447.6006
# ====> Epoch: 229 Average loss: 449.1256
# ====> Test set loss: 450.7609
# ====> Epoch: 230 Average loss: 447.7479
# ====> Test set loss: 452.9938
# ====> Epoch: 231 Average loss: 449.3327
# ====> Test set loss: 450.4873
# ====> Epoch: 232 Average loss: 449.9345
# ====> Test set loss: 453.1523
# ====> Epoch: 233 Average loss: 450.0324
# ====> Test set loss: 454.1473
# ====> Epoch: 234 Average loss: 448.2920
# ====> Test set loss: 452.4568
# ====> Epoch: 235 Average loss: 448.9514
# ====> Test set loss: 455.9187
# ====> Epoch: 236 Average loss: 449.5607
# ====> Test set loss: 452.5600
# ====> Epoch: 237 Average loss: 450.8801
# ====> Test set loss: 451.0250
# ====> Epoch: 238 Average loss: 450.1203
# ====> Test set loss: 457.7861
# ====> Epoch: 239 Average loss: 448.5817
# ====> Test set loss: 451.7016
# ====> Epoch: 240 Average loss: 450.3246
# ====> Test set loss: 453.6050
# ====> Epoch: 241 Average loss: 449.8117
# ====> Test set loss: 453.6138
# ====> Epoch: 242 Average loss: 451.5111
# ====> Test set loss: 452.4519
# ====> Epoch: 243 Average loss: 450.8939
# ====> Test set loss: 456.3675
# ====> Epoch: 244 Average loss: 448.2927
# ====> Test set loss: 452.2681
# ====> Epoch: 245 Average loss: 447.1120
# ====> Test set loss: 453.0500
# ====> Epoch: 246 Average loss: 449.9170
# ====> Test set loss: 456.1460
# ====> Epoch: 247 Average loss: 450.9489
# ====> Test set loss: 454.4663
# ====> Epoch: 248 Average loss: 450.3171
# ====> Test set loss: 451.5225
# ====> Epoch: 249 Average loss: 450.0574
# ====> Test set loss: 451.2391
# ====> Epoch: 250 Average loss: 451.5495
# ====> Test set loss: 457.0133
# ====> Epoch: 251 Average loss: 449.5935
# ====> Test set loss: 453.3593
# ====> Epoch: 252 Average loss: 449.0632
# ====> Test set loss: 450.1104
# ====> Epoch: 253 Average loss: 450.2078
# ====> Test set loss: 453.8218
# ====> Epoch: 254 Average loss: 447.9700
# ====> Test set loss: 453.8246
# ====> Epoch: 255 Average loss: 450.3652
# ====> Test set loss: 452.7242
# ====> Epoch: 256 Average loss: 451.7030
# ====> Test set loss: 451.2308
# ====> Epoch: 257 Average loss: 449.2710
# ====> Test set loss: 449.9329
# ====> Epoch: 258 Average loss: 449.4690
# ====> Test set loss: 454.0083
# ====> Epoch: 259 Average loss: 448.6769
# ====> Test set loss: 456.9967
# ====> Epoch: 260 Average loss: 450.5878
# ====> Test set loss: 454.8870
# ====> Epoch: 261 Average loss: 449.3120
# ====> Test set loss: 452.5793
# ====> Epoch: 262 Average loss: 450.1197
# ====> Test set loss: 454.3304
# ====> Epoch: 263 Average loss: 447.9405
# ====> Test set loss: 448.6841
# ====> Epoch: 264 Average loss: 449.4936
# ====> Test set loss: 452.0647
# ====> Epoch: 265 Average loss: 447.9745
# ====> Test set loss: 455.0167
# ====> Epoch: 266 Average loss: 451.0459
# ====> Test set loss: 446.2666
# ====> Epoch: 267 Average loss: 448.3400
# ====> Test set loss: 453.5176
# ====> Epoch: 268 Average loss: 449.3420
# ====> Test set loss: 452.1908
# ====> Epoch: 269 Average loss: 451.0348
# ====> Test set loss: 449.7760
# ====> Epoch: 270 Average loss: 448.2125
# ====> Test set loss: 450.5719
# ====> Epoch: 271 Average loss: 448.2829
# ====> Test set loss: 448.8916
# ====> Epoch: 272 Average loss: 449.5287
# ====> Test set loss: 458.2291
# ====> Epoch: 273 Average loss: 449.8040
# ====> Test set loss: 454.3680
# ====> Epoch: 274 Average loss: 448.7349
# ====> Test set loss: 451.6931
# ====> Epoch: 275 Average loss: 450.8388
# ====> Test set loss: 451.1525
# ====> Epoch: 276 Average loss: 451.5999
# ====> Test set loss: 451.7428
# ====> Epoch: 277 Average loss: 449.3512
# ====> Test set loss: 451.2152
# ====> Epoch: 278 Average loss: 450.6868
# ====> Test set loss: 455.7632
# ====> Epoch: 279 Average loss: 448.7607
# ====> Test set loss: 454.9824
# ====> Epoch: 280 Average loss: 450.1998
# ====> Test set loss: 452.6142
# ====> Epoch: 281 Average loss: 449.1175
# ====> Test set loss: 453.9924
# ====> Epoch: 282 Average loss: 447.0052
# ====> Test set loss: 447.6936
# ====> Epoch: 283 Average loss: 449.6407
# ====> Test set loss: 452.3012
# ====> Epoch: 284 Average loss: 448.1061
# ====> Test set loss: 451.0287
# ====> Epoch: 285 Average loss: 450.4832
# ====> Test set loss: 452.0505
# ====> Epoch: 286 Average loss: 449.5837
# ====> Test set loss: 453.5746
# ====> Epoch: 287 Average loss: 448.7845
# ====> Test set loss: 452.0733
# ====> Epoch: 288 Average loss: 448.3051
# ====> Test set loss: 449.6352
# ====> Epoch: 289 Average loss: 450.9225
# ====> Test set loss: 453.2306
# ====> Epoch: 290 Average loss: 450.7508
# ====> Test set loss: 451.7596
# ====> Epoch: 291 Average loss: 448.8264
# ====> Test set loss: 449.4582
# ====> Epoch: 292 Average loss: 448.8694
# ====> Test set loss: 452.5833
# ====> Epoch: 293 Average loss: 448.9718
# ====> Test set loss: 454.5827
# ====> Epoch: 294 Average loss: 450.4842
# ====> Test set loss: 451.4956
# ====> Epoch: 295 Average loss: 449.0287
# ====> Test set loss: 452.0834
# ====> Epoch: 296 Average loss: 450.1054
# ====> Test set loss: 451.4370
# ====> Epoch: 297 Average loss: 451.1590
# ====> Test set loss: 459.5468
# ====> Epoch: 298 Average loss: 448.8465
# ====> Test set loss: 450.6421
# ====> Epoch: 299 Average loss: 449.8154
# ====> Test set loss: 455.5303
# ====> Epoch: 300 Average loss: 448.3163
# ====> Test set loss: 451.8545
# ====> Epoch: 301 Average loss: 448.7403
# ====> Test set loss: 462.7094
# ====> Epoch: 302 Average loss: 448.2498
# ====> Test set loss: 455.2057
# ====> Epoch: 303 Average loss: 449.0153
# ====> Test set loss: 450.4582
# ====> Epoch: 304 Average loss: 448.7355
# ====> Test set loss: 449.9998
# ====> Epoch: 305 Average loss: 449.4895
# ====> Test set loss: 453.7462
# ====> Epoch: 306 Average loss: 448.0274
# ====> Test set loss: 449.0574
# ====> Epoch: 307 Average loss: 450.0741
# ====> Test set loss: 449.9341
# ====> Epoch: 308 Average loss: 448.0414
# ====> Test set loss: 459.6836
# ====> Epoch: 309 Average loss: 448.2342
# ====> Test set loss: 451.1350
# ====> Epoch: 310 Average loss: 449.0584
# ====> Test set loss: 450.9339
# ====> Epoch: 311 Average loss: 447.9029
# ====> Test set loss: 455.1268
# ====> Epoch: 312 Average loss: 448.7037
# ====> Test set loss: 456.2401
# ====> Epoch: 313 Average loss: 448.6825
# ====> Test set loss: 454.4664
# ====> Epoch: 314 Average loss: 450.1459
# ====> Test set loss: 459.4301
# ====> Epoch: 315 Average loss: 447.8455
# ====> Test set loss: 454.0082
# ====> Epoch: 316 Average loss: 449.7352
# ====> Test set loss: 451.8815
# ====> Epoch: 317 Average loss: 449.5256
# ====> Test set loss: 452.1318
# ====> Epoch: 318 Average loss: 448.2400
# ====> Test set loss: 452.5729
# ====> Epoch: 319 Average loss: 448.7671
# ====> Test set loss: 451.3128
# ====> Epoch: 320 Average loss: 449.0211
# ====> Test set loss: 452.3838
# ====> Epoch: 321 Average loss: 446.5749
# ====> Test set loss: 452.2086
# ====> Epoch: 322 Average loss: 447.9178
# ====> Test set loss: 450.0540
# ====> Epoch: 323 Average loss: 449.1037
# ====> Test set loss: 453.9260
# ====> Epoch: 324 Average loss: 447.2722
# ====> Test set loss: 450.7174
# ====> Epoch: 325 Average loss: 448.1970
# ====> Test set loss: 452.0575
# ====> Epoch: 326 Average loss: 448.6818
# ====> Test set loss: 451.1468
# ====> Epoch: 327 Average loss: 449.8896
# ====> Test set loss: 453.7212
# ====> Epoch: 328 Average loss: 447.2023
# ====> Test set loss: 452.1146
# ====> Epoch: 329 Average loss: 449.0849
# ====> Test set loss: 456.2228
# ====> Epoch: 330 Average loss: 449.5077
# ====> Test set loss: 453.5417
# ====> Epoch: 331 Average loss: 448.6124
# ====> Test set loss: 453.2920
# ====> Epoch: 332 Average loss: 448.8051
# ====> Test set loss: 451.8741
# ====> Epoch: 333 Average loss: 449.5589
# ====> Test set loss: 454.4525
# ====> Epoch: 334 Average loss: 449.1859
# ====> Test set loss: 452.4182
# ====> Epoch: 335 Average loss: 449.2900
# ====> Test set loss: 455.7971
# ====> Epoch: 336 Average loss: 447.9637
# ====> Test set loss: 452.2248
# ====> Epoch: 337 Average loss: 449.5961
# ====> Test set loss: 458.0435
# ====> Epoch: 338 Average loss: 448.0701
# ====> Test set loss: 450.4312
# ====> Epoch: 339 Average loss: 448.3036
# ====> Test set loss: 451.0192
# ====> Epoch: 340 Average loss: 447.9125
# ====> Test set loss: 449.8858
# ====> Epoch: 341 Average loss: 449.8655
# ====> Test set loss: 449.4885
# ====> Epoch: 342 Average loss: 448.2937
# ====> Test set loss: 456.9385
# ====> Epoch: 343 Average loss: 448.7964
# ====> Test set loss: 453.1346
# ====> Epoch: 344 Average loss: 449.8051
# ====> Test set loss: 458.8623
# ====> Epoch: 345 Average loss: 448.2057
# ====> Test set loss: 452.9961
# ====> Epoch: 346 Average loss: 449.1724
# ====> Test set loss: 453.6778
# ====> Epoch: 347 Average loss: 447.3807
# ====> Test set loss: 454.3799
# ====> Epoch: 348 Average loss: 448.3748
# ====> Test set loss: 449.4738
# ====> Epoch: 349 Average loss: 446.6045
# ====> Test set loss: 454.7267
# ====> Epoch: 350 Average loss: 448.2367
# ====> Test set loss: 457.1298
# ====> Epoch: 351 Average loss: 447.7261
# ====> Test set loss: 453.6728
# ====> Epoch: 352 Average loss: 449.1310
# ====> Test set loss: 454.1749
# ====> Epoch: 353 Average loss: 447.9978
# ====> Test set loss: 462.2222
# ====> Epoch: 354 Average loss: 450.1308
# ====> Test set loss: 453.3742
# ====> Epoch: 355 Average loss: 448.0926
# ====> Test set loss: 453.4674
# ====> Epoch: 356 Average loss: 447.4847
# ====> Test set loss: 455.3028
# ====> Epoch: 357 Average loss: 447.8240
# ====> Test set loss: 449.7335
# ====> Epoch: 358 Average loss: 450.1455
# ====> Test set loss: 450.3740
# ====> Epoch: 359 Average loss: 447.6665
# ====> Test set loss: 458.8543
# ====> Epoch: 360 Average loss: 449.0382
# ====> Test set loss: 448.7119
# ====> Epoch: 361 Average loss: 448.3345
# ====> Test set loss: 449.7712
# ====> Epoch: 362 Average loss: 447.1650
# ====> Test set loss: 450.8992
# ====> Epoch: 363 Average loss: 448.8719
# ====> Test set loss: 453.3314
# ====> Epoch: 364 Average loss: 449.0090
# ====> Test set loss: 450.6009
# ====> Epoch: 365 Average loss: 447.3156
# ====> Test set loss: 456.2234
# ====> Epoch: 366 Average loss: 449.1123
# ====> Test set loss: 451.4551
# ====> Epoch: 367 Average loss: 448.7440
# ====> Test set loss: 455.0358
# ====> Epoch: 368 Average loss: 447.7102
# ====> Test set loss: 450.2575
# ====> Epoch: 369 Average loss: 448.9263
# ====> Test set loss: 458.9539
# ====> Epoch: 370 Average loss: 447.8778
# ====> Test set loss: 452.8595
# ====> Epoch: 371 Average loss: 447.2477
# ====> Test set loss: 453.9074
# ====> Epoch: 372 Average loss: 448.1462
# ====> Test set loss: 453.4571
# ====> Epoch: 373 Average loss: 447.1071
# ====> Test set loss: 453.8082
# ====> Epoch: 374 Average loss: 446.5562
# ====> Test set loss: 450.5131
# ====> Epoch: 375 Average loss: 447.2857
# ====> Test set loss: 453.2435
# ====> Epoch: 376 Average loss: 447.8530
# ====> Test set loss: 453.8760
# ====> Epoch: 377 Average loss: 449.8527
# ====> Test set loss: 453.5062
# ====> Epoch: 378 Average loss: 447.9263
# ====> Test set loss: 456.1043
# ====> Epoch: 379 Average loss: 447.7706
# ====> Test set loss: 451.2649
# ====> Epoch: 380 Average loss: 448.6218
# ====> Test set loss: 453.4180
# ====> Epoch: 381 Average loss: 446.7955
# ====> Test set loss: 453.2536
# ====> Epoch: 382 Average loss: 447.0464
# ====> Test set loss: 458.0769
# ====> Epoch: 383 Average loss: 449.1347
# ====> Test set loss: 451.1649
# ====> Epoch: 384 Average loss: 446.7213
# ====> Test set loss: 447.4127
# ====> Epoch: 385 Average loss: 448.3089
# ====> Test set loss: 452.8667
# ====> Epoch: 386 Average loss: 447.1340
# ====> Test set loss: 457.0416
# ====> Epoch: 387 Average loss: 449.5813
# ====> Test set loss: 452.6301
# ====> Epoch: 388 Average loss: 448.9597
# ====> Test set loss: 451.1346
# ====> Epoch: 389 Average loss: 447.1774
# ====> Test set loss: 446.5403
# ====> Epoch: 390 Average loss: 447.2962
# ====> Test set loss: 448.9825
# ====> Epoch: 391 Average loss: 449.8969
# ====> Test set loss: 452.4165
# ====> Epoch: 392 Average loss: 448.2154
# ====> Test set loss: 453.9775
# ====> Epoch: 393 Average loss: 448.1897
# ====> Test set loss: 452.5907
# ====> Epoch: 394 Average loss: 447.2248
# ====> Test set loss: 455.1322
# ====> Epoch: 395 Average loss: 448.5103
# ====> Test set loss: 451.2759
# ====> Epoch: 396 Average loss: 446.3017
# ====> Test set loss: 450.2006
# ====> Epoch: 397 Average loss: 447.8763
# ====> Test set loss: 453.1435
# ====> Epoch: 398 Average loss: 447.2283
# ====> Test set loss: 454.4022
# ====> Epoch: 399 Average loss: 448.5791
# ====> Test set loss: 454.7986
# ====> Epoch: 400 Average loss: 447.8118
# ====> Test set loss: 452.2875

# %%
plt.plot(np.array(train_losses),'r')
plt.show()
plt.plot(np.array(test_losses),'b')
plt.show()

# %% [markdown]
# ### Sample from trained model

# %%
# Generate a sequence of 10 time steps
sampler_test = PeriodicSamp(1, obs_dim, np.cos, 1)
latent_test, obs_test = sampler_test.sample_all(10)
obs_test = np.transpose(obs_test, (1, 0, 2))
obs_test_pre = obs_test[0,:9,:]
obs_test_after = obs_test[0,1:,:]
print(obs_test_pre.shape)
print(obs_test_after.shape)

model.eval()
train_data = torch.Tensor(obs_test_pre).to(device)
train_data = train_data.reshape(1, 9, 50)
print(train_data.shape)

mu, logvar,_,_ = model.forward(train_data)
covar = torch.diag_embed(torch.exp(logvar))
std_obs = torch.distributions.MultivariateNormal(mu, covar)
obs_sample = std_obs.sample()
print(obs_sample.shape)
obs_sample = obs_sample.cpu().numpy()
# Out:
# (9, 50)
# (9, 50)
# torch.Size([1, 9, 50])
# torch.Size([1, 9, 50])

# %%
x1 = np.arange(1, 10)
for i in range(50):
  plt.plot(x1, obs_sample[0, :, i], marker = 'o', markersize = 4)
  plt.xlabel('Time')
  plt.ylabel('Magnitude')
  plt.title('Reconstructed Signal');
plt.show()

# %%
for i in range(50):
  plt.plot(x1, obs_test_after[:, i], marker = 'o', markersize = 4)
  plt.xlabel('Time')
  plt.ylabel('Magnitude')
  plt.title('True Signal');
plt.show()
