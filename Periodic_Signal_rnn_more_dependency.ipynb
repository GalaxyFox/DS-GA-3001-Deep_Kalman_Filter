# %%
from __future__ import print_function
import numpy as np
import math
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import argparse
import torch
import torch.utils.data
from torch import nn, optim
from torch.nn import functional as F
from torchvision import datasets, transforms
from torchvision.utils import save_image

# %% [markdown]
# ## Generate Periodic Signal

# %% [markdown]
# #### 1. Generate with specified latent dynamic model (nonlinear everywhere)

# %%
# Nonlinear functions (Input can be arrays)
def sigmoid(x):
    return 1 / (1 + math.exp(-x))


def sq(x):
    return x ** 2


def sqrtplus(x):
    sgn = np.sign(x)
    y = np.multiply(sgn, np.sqrt(np.absolute(x)))
    return y


def const_zero(x):
    return np.zeros(len(x))

def twosin2_point1(x):
    return 2 * np.sin(2*x) - 0.1

# %%
class TwoFuncSamp():
    def __init__(self, n_obs, obs_dim, fh1, fh2, fob1, fob2, coef_fh1, coef_fh2, coef_fob1, coef_fob2):
        
        self.h_dim = 2
        self.fh1 = fh1
        self.fh2 = fh2
        self.fob1 = fob1
        self.fob2 = fob2
        self.coef_fh1 = coef_fh1
        self.coef_fh2 = coef_fh2
        self.coef_fob1 = coef_fob1
        self.coef_fob2 = coef_fob2
        
        # Initial state multivariate normal with mean = 0.1 and covariance matrix = Diag(2)
        self.obs_dim = obs_dim
        self.n_obs = n_obs
        self.h_dim = 2
        self.initial_mean = np.array([0, 0.5])
        self.initial_log_diag_sq = np.log(np.array([1, 1.1]))

        
        # Dimension transformation from latent to observation
        self.emit_mat = np.random.uniform(0.95, 1.05, self.h_dim).reshape(self.h_dim, 1)
        
    
    def sample_all(self, n_timesteps, random_seed = None):
        mus = np.zeros([n_timesteps, self.h_dim])
        log_diag_sigmas = np.zeros([n_timesteps, self.h_dim])
        observations = np.zeros([n_timesteps, self.n_obs, self.obs_dim])
        
        if random_seed is not None:
            np.random.seed(random_seed)

        # Initialize hidden mean and diagonal entries of covariance matrix (with small Gaussian noise)
        mus[0, :] = self.coef_fh1 * self.fh1(self.initial_mean) + self.coef_fh2 * self.fh2(self.initial_mean) + 0.1 * np.random.normal(0, 1, self.h_dim)
        log_diag_sigmas[0, :] = self.coef_fh1 * self.fh1(self.initial_log_diag_sq) + self.coef_fh2 * self.fh2(self.initial_log_diag_sq) + 0.1 * np.random.normal(0, 1, self.h_dim)
        
        # Initialize observation (Latent is Gaussian, linear transform to modify dimension)
        for j in range(self.n_obs):
            samp_h = np.random.multivariate_normal(mus[0, :], np.diag(np.exp(log_diag_sigmas[0, :])), self.obs_dim)
            pre_samp_obs = np.dot(samp_h, self.emit_mat)
            temp = self.coef_fob1 * self.fob1(pre_samp_obs) + self.coef_fob2 * self.fob2(pre_samp_obs)
            temp = temp.flatten()
            observations[0, j, :] = temp + np.random.normal(0, 1, self.obs_dim)
        
        for i in range(1, n_timesteps):
            # Update hidden mean and diagonal entries of covariance matrix at time step i (with small Gaussian noise)
            mus[i, :] = self.coef_fh1 * self.fh1(mus[i - 1, :]) + self.coef_fh2 * self.fh2(mus[i - 1, :]) + 0.1 * np.random.normal(0, 1, self.h_dim)
            log_diag_sigmas[i, :] = self.coef_fh1 * self.fh1(log_diag_sigmas[i - 1, :]) + self.coef_fh2 * self.fh2(log_diag_sigmas[i - 1, :]) + 0.1 * np.random.normal(0, 1, self.h_dim)
            
            # Generate a series of observation vectors
            for j in range(self.n_obs):
                samp_h = np.random.multivariate_normal(mus[i, :], np.diag(np.exp(log_diag_sigmas[i, :])), self.obs_dim)
                pre_samp_obs = np.dot(samp_h, self.emit_mat)
                temp = self.coef_fob1 * self.fob1(pre_samp_obs) + self.coef_fob2 * self.fob2(pre_samp_obs)
                temp = temp.flatten()
                observations[i, j, :] = temp + np.random.normal(0, 1, self.obs_dim)
        return mus, log_diag_sigmas, observations

# %%
# Sampler following Professor's suggestion
class PeriodicSamp():
    def __init__(self, n_obs, obs_dim, f_hidden, coef_fh):
        self.h_dim = 2
        self.obs_dim = obs_dim
        self.fh = f_hidden
        self.coef_fh = coef_fh
        
        # Initial state multivariate normal with mean = 0.1 and covariance matrix = Diag(2)
        self.n_obs = n_obs
        self.initial_state = np.random.multivariate_normal(np.zeros(self.h_dim), np.eye(self.h_dim), self.n_obs)

        # We do not focus on VAE, therefore the emission function is linear and should be easy to learn.
        self.emission_mat = np.random.uniform(0.95, 1.05, self.h_dim * self.obs_dim).reshape(self.obs_dim, self.h_dim)
        
    
    def sample_all(self, n_timesteps, random_seed = None):
        latents = np.zeros([n_timesteps, self.n_obs, self.h_dim])
        observations = np.zeros([n_timesteps, self.n_obs, self.obs_dim])
        
        if random_seed is not None:
            np.random.seed(random_seed)

        for i in range(self.n_obs):
          diag_h = np.random.uniform(1, 5, self.h_dim)
          diag_o = np.random.uniform(1, 5, self.obs_dim)

          # Hidden state is multivariate Gaussian plus iid Gaussian noise
          latents[0, i, :] = np.random.multivariate_normal(self.coef_fh * self.fh(self.initial_state[i]), 0.01 * np.diag(diag_h))
          # Initialize observation (linear transformation + Gaussian noise)
          observations[0, i, :] = np.matmul(self.emission_mat, latents[0, i, :]) + 0.1 * np.random.multivariate_normal(np.zeros(self.obs_dim), np.diag(diag_o))   
      

        for t in range(1, n_timesteps):
            for i in range(self.n_obs):
              diag_h = np.random.uniform(1, 5, self.h_dim)
              diag_o = np.random.uniform(1, 5, self.obs_dim)
              # Hidden state is multivariate Gaussian plus iid Gaussian noise
              if t == 1:
                latents[t, i, :] = np.random.multivariate_normal(0.4 * self.coef_fh * self.fh(latents[t - 1, i, :]) + 0.6 * self.coef_fh * self.fh(self.initial_state[i]), 0.01 * np.diag(diag_h))
              else:
                latents[t, i, :] = np.random.multivariate_normal(0.4 * self.coef_fh * self.fh(latents[t - 1, i, :]) + 0.6 * self.coef_fh * self.fh(latents[t - 2, i, :]), 0.01 * np.diag(diag_h))
              # Initialize observation (linear transformation + Gaussian noise)
              observations[t, i, :] = np.matmul(self.emission_mat, latents[t, i, :]) + 0.1 * np.random.multivariate_normal(np.zeros(self.obs_dim), np.diag(diag_o))
        return latents, observations

# %%
h_dim = 2
obs_dim = 50
n_obs = 10000
n_timestep = 10

sampler2 = PeriodicSamp(n_obs, obs_dim, np.cos, 2)

# %%
latents, obs = sampler2.sample_all(n_timestep)

# %%
print(obs.shape)
# Out:
# (10, 10000, 50)

# %%
obs = np.transpose(obs, (1, 0, 2))
print(obs.shape)
# Out:
# (10000, 10, 50)

# %%
# Plot the temporal trend for each dimension of first five observations
x1 = np.arange(n_timestep)
for n in range(10):
    for i in range(sampler2.obs_dim):
        plt.plot(x1, obs[n, :, i], marker = 'o', markersize = 4)

    plt.xlabel('Time')
    plt.ylabel('Magnitude')
    plt.title('Each dimension of observation '+ str(n + 1));
    plt.show()

# %%
X_range = np.arange(0, 9)
Y_range = np.arange(1, 10)
X = obs[:, X_range, :]
Y = obs[:, Y_range, :]

# %%
print(X.shape)
print(Y.shape)
# Out:
# (10000, 9, 50)
# (10000, 9, 50)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 1)

# %%
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
# Out:
# (8000, 9, 50) (8000, 9, 50) (2000, 9, 50) (2000, 9, 50)

# %%
train_X_small = X_train[0: 5]
test_X_small = X_test[0: 2]
train_Y_small = Y_train[0: 5]
test_Y_small = Y_test[0: 2]

# %% [markdown]
# ## Prepare Dataset

# %%
batch_size = 16
seed = 1
epochs = 400
cuda = True
log_interval = 10
h_d = 16
l_d = 8
sample_size=10


device = torch.device("cuda" if cuda else "cpu")

kwargs = {'num_workers': 0, 'pin_memory': True} if cuda else {}

"""

train_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=True, download=True,
                   transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)



test_loader = torch.utils.data.DataLoader(
    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),
    batch_size=batch_size, shuffle=True, **kwargs)

"""
# Out:
# "\n\ntrain_loader = torch.utils.data.DataLoader(\n    datasets.MNIST('./data', train=True, download=True,\n                   transform=transforms.ToTensor()),\n    batch_size=batch_size, shuffle=True, **kwargs)\n\n\n\ntest_loader = torch.utils.data.DataLoader(\n    datasets.MNIST('./data', train=False, transform=transforms.ToTensor()),\n    batch_size=batch_size, shuffle=True, **kwargs)\n\n"

# %% [markdown]
# #### Dataset Object

# %%
class SignalData():
    def __init__(self, train_obs, train_tar, test_obs, test_tar, test = False, transform = None):
        self.test = test
        self.transform = transform

        if (self.test == False):
          self.obs = torch.from_numpy(train_obs).float()
          self.targets = torch.from_numpy(train_tar).float()

        else:      
          self.obs = test_obs
          self.targets = test_tar

    def __len__(self):
        return len(self.obs)
    
    def __getitem__(self, index):
        if self.transform is not None:
            ob = self.transform(self.obs[index])
            tar = self.transform(self.targets[index])
        else:
            ob = self.obs[index]
            tar = self.targets[index]
        return ob, tar

# %% [markdown]
# ### Create Dataloader

# %%
train_set = SignalData(X_train, Y_train, X_test, Y_test, test = False, transform = None)
test_set = SignalData(X_train, Y_train, X_test, Y_test, test = True, transform = None)

# %%
train_set_small = SignalData(train_X_small, train_Y_small, test_X_small, test_Y_small, test = False, transform = None)
test_set_small = SignalData(train_X_small, train_Y_small, test_X_small, test_Y_small, test = True, transform = None)

# %%
train_loader = torch.utils.data.DataLoader(train_set, batch_size=batch_size, shuffle = True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=batch_size, shuffle = False, **kwargs)

# %%
train_loader_small = torch.utils.data.DataLoader(train_set_small, batch_size=1, shuffle = True, **kwargs)
test_loader_small = torch.utils.data.DataLoader(test_set_small, batch_size=1, shuffle = False, **kwargs)

# %% [markdown]
# ### Model Definition

# %%
class VAE(nn.Module):
    def __init__(self):
        super(VAE, self).__init__()

        # Encoder
        self.fc1 = nn.Linear(50, h_d)
        self.fc21 = nn.Linear(h_d, l_d)
        self.fc22 = nn.Linear(h_d, l_d)
        
        #transition layer
        input_dim = l_d
        self.rnn_mu = nn.RNN(input_size=input_dim,hidden_size=l_d,batch_first=True)
        self.rnn_sigma = nn.RNN(input_size=input_dim,hidden_size=l_d,batch_first=True)
        
        # Decoder should also be a probability distribution
        self.fc3 = nn.Linear(l_d, h_d)
        self.fc4 = nn.Linear(h_d, 50)
        self.fc5 = nn.Linear(h_d, 50)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize1(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std
    
    def transition(self, z):
        mu2,_ = self.rnn_mu(z)
        logvar2,_ = self.rnn_sigma(z)
        return mu2,logvar2
    
    def reparameterize2(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mu + eps*std

    def decode(self, z):
        h3 = torch.tanh(self.fc3(z))
        return self.fc4(h3), self.fc5(h3)

    def forward(self, x):
        mu1, logvar1 = self.encode(x.view(-1,50))
        #z1 = self.reparameterize1(mu1, logvar1)
        #mu2, logvar2 = self.transition(z1)
        #z2 = self.reparameterize2(mu2, logvar2)
        
        mu = torch.empty(sample_size, x.shape[0], x.shape[1], l_d , dtype=torch.float).to(device)
        logvar = torch.empty(sample_size, x.shape[0], x.shape[1], l_d , dtype=torch.float).to(device)
        for i in range(sample_size):
            z1 = self.reparameterize1(mu1, logvar1)
            z1 = z1.reshape(-1,9,l_d)
            mu2, logvar2 = self.transition(z1)
            mu[i] = mu2
            logvar[i] = logvar2
        z2 = self.reparameterize2(mu[0], logvar[0])
        
        mu_obs, logvar_obs = self.decode(z2)
        
        return mu_obs, logvar_obs, mu, logvar

# %%
model = VAE().to(device)
#adam optimizer
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
# Reconstruction + KL divergence losses summed over all elements and batch
def loss_function(x, mu_obs, logvar_obs, mu, logvar):
    covar = torch.diag_embed(torch.exp(logvar_obs))
    n = torch.distributions.MultivariateNormal(mu_obs, covariance_matrix = covar)
    neg_llh = torch.sum(-n.log_prob(x))

    # see Appendix B from VAE paper:
    # Kingma and Welling. Auto-Encoding Variational Bayes. ICLR, 2014
    # https://arxiv.org/abs/1312.6114
    # 0.5 * sum(1 + log(sigma^2) - mu^2 - sigma^2)
    KLD = -0.5 * torch.sum(1 + logvar[0,:,0,:] - mu[0,:,0,:].pow(2) - logvar[0,:,0,:].exp())
    EKLD = 0
    for i in range(1,9):        
        tmp = -0.5 * torch.sum(1 + logvar[:,:,i,:] - mu[:,:,i,:].pow(2) - logvar[:,:,i,:].exp())/sample_size
        EKLD += tmp
    

    return neg_llh + KLD + EKLD

# %% [markdown]
# ### Define training and testing algorithm

# %%
def train(epoch):
    model.train()
    train_loss = 0
    for batch_idx, (obs, target) in enumerate(train_loader):
        obs = obs.to(device)
        target = target.to(device)
        optimizer.zero_grad()
        mu_obs, logvar_obs, mu, logvar = model(obs.float())
        loss = loss_function(target.float(), mu_obs, logvar_obs, mu, logvar)
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        #if batch_idx % log_interval == 0:
         #   print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
          #      epoch, batch_idx * len(img), len(train_loader.dataset),
           #     100. * batch_idx / len(train_loader),
            #    loss.item() / len(img)))

    print('====> Epoch: {} Average loss: {:.4f}'.format(
          epoch, train_loss / len(train_loader.dataset)))
    return train_loss

# %%
def test(epoch):
    model.eval()
    test_loss = 0
    with torch.no_grad():
        for i, (obs, target) in enumerate(test_loader):
            obs = obs.to(device)
            target = target.to(device)
            mu_obs, logvar_obs, mu, logvar = model(obs.float())
            test_loss += loss_function(target.float(), mu_obs, logvar_obs, mu, logvar).item()
    test_loss /= len(test_loader.dataset)
    print('====> Test set loss: {:.4f}'.format(test_loss))
    return test_loss

# %% [markdown]
# ### Run Training

# %%
train_losses = []
test_losses = []
for epoch in range(1, epochs + 1):
    train_loss = train(epoch)
    test_loss = test(epoch)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
# Out:
# ====> Epoch: 1 Average loss: 670.2741
# ====> Test set loss: 534.8302
# ====> Epoch: 2 Average loss: 457.2433
# ====> Test set loss: 421.9041
# ====> Epoch: 3 Average loss: 413.0127
# ====> Test set loss: 407.8706
# ====> Epoch: 4 Average loss: 398.6348
# ====> Test set loss: 382.9650
# ====> Epoch: 5 Average loss: 376.7050
# ====> Test set loss: 367.7539
# ====> Epoch: 6 Average loss: 362.2729
# ====> Test set loss: 348.0434
# ====> Epoch: 7 Average loss: 343.5337
# ====> Test set loss: 329.0632
# ====> Epoch: 8 Average loss: 328.9303
# ====> Test set loss: 323.4215
# ====> Epoch: 9 Average loss: 321.9389
# ====> Test set loss: 315.9693
# ====> Epoch: 10 Average loss: 318.3161
# ====> Test set loss: 312.4698
# ====> Epoch: 11 Average loss: 314.1063
# ====> Test set loss: 309.8608
# ====> Epoch: 12 Average loss: 310.7285
# ====> Test set loss: 310.5148
# ====> Epoch: 13 Average loss: 310.0907
# ====> Test set loss: 301.6431
# ====> Epoch: 14 Average loss: 306.4571
# ====> Test set loss: 304.5909
# ====> Epoch: 15 Average loss: 305.1271
# ====> Test set loss: 301.6297
# ====> Epoch: 16 Average loss: 303.0034
# ====> Test set loss: 297.4637
# ====> Epoch: 17 Average loss: 302.1015
# ====> Test set loss: 300.8315
# ====> Epoch: 18 Average loss: 298.6730
# ====> Test set loss: 296.8452
# ====> Epoch: 19 Average loss: 298.4952
# ====> Test set loss: 299.0247
# ====> Epoch: 20 Average loss: 297.4883
# ====> Test set loss: 294.3570
# ====> Epoch: 21 Average loss: 297.4184
# ====> Test set loss: 295.5761
# ====> Epoch: 22 Average loss: 297.1389
# ====> Test set loss: 291.4096
# ====> Epoch: 23 Average loss: 295.6933
# ====> Test set loss: 302.2774
# ====> Epoch: 24 Average loss: 295.2420
# ====> Test set loss: 292.5006
# ====> Epoch: 25 Average loss: 293.0675
# ====> Test set loss: 289.9857
# ====> Epoch: 26 Average loss: 294.0750
# ====> Test set loss: 290.7118
# ====> Epoch: 27 Average loss: 291.0809
# ====> Test set loss: 288.1780
# ====> Epoch: 28 Average loss: 293.8462
# ====> Test set loss: 293.0107
# ====> Epoch: 29 Average loss: 291.1153
# ====> Test set loss: 289.0968
# ====> Epoch: 30 Average loss: 290.7270
# ====> Test set loss: 286.4591
# ====> Epoch: 31 Average loss: 288.9408
# ====> Test set loss: 288.1493
# ====> Epoch: 32 Average loss: 289.3399
# ====> Test set loss: 289.5031
# ====> Epoch: 33 Average loss: 288.8840
# ====> Test set loss: 287.4338
# ====> Epoch: 34 Average loss: 289.1572
# ====> Test set loss: 290.7789
# ====> Epoch: 35 Average loss: 287.9293
# ====> Test set loss: 286.3832
# ====> Epoch: 36 Average loss: 290.0067
# ====> Test set loss: 288.2521
# ====> Epoch: 37 Average loss: 288.7028
# ====> Test set loss: 299.1247
# ====> Epoch: 38 Average loss: 287.7793
# ====> Test set loss: 283.5033
# ====> Epoch: 39 Average loss: 287.4230
# ====> Test set loss: 284.4801
# ====> Epoch: 40 Average loss: 288.1024
# ====> Test set loss: 284.8954
# ====> Epoch: 41 Average loss: 287.7540
# ====> Test set loss: 285.6516
# ====> Epoch: 42 Average loss: 287.4767
# ====> Test set loss: 285.7859
# ====> Epoch: 43 Average loss: 286.2268
# ====> Test set loss: 290.2419
# ====> Epoch: 44 Average loss: 286.1730
# ====> Test set loss: 283.0248
# ====> Epoch: 45 Average loss: 285.4493
# ====> Test set loss: 284.6208
# ====> Epoch: 46 Average loss: 286.3337
# ====> Test set loss: 291.3753
# ====> Epoch: 47 Average loss: 286.2275
# ====> Test set loss: 282.4461
# ====> Epoch: 48 Average loss: 285.7507
# ====> Test set loss: 283.7933
# ====> Epoch: 49 Average loss: 285.7178
# ====> Test set loss: 287.8523
# ====> Epoch: 50 Average loss: 284.3953
# ====> Test set loss: 283.9971
# ====> Epoch: 51 Average loss: 285.4018
# ====> Test set loss: 288.2982
# ====> Epoch: 52 Average loss: 285.7022
# ====> Test set loss: 286.8477
# ====> Epoch: 53 Average loss: 285.1135
# ====> Test set loss: 282.3209
# ====> Epoch: 54 Average loss: 285.3284
# ====> Test set loss: 281.2372
# ====> Epoch: 55 Average loss: 285.2240
# ====> Test set loss: 282.2477
# ====> Epoch: 56 Average loss: 284.5448
# ====> Test set loss: 280.3420
# ====> Epoch: 57 Average loss: 284.5217
# ====> Test set loss: 279.3654
# ====> Epoch: 58 Average loss: 284.3236
# ====> Test set loss: 282.2170
# ====> Epoch: 59 Average loss: 283.3074
# ====> Test set loss: 281.5047
# ====> Epoch: 60 Average loss: 283.8845
# ====> Test set loss: 279.4401
# ====> Epoch: 61 Average loss: 283.2388
# ====> Test set loss: 280.4302
# ====> Epoch: 62 Average loss: 283.8780
# ====> Test set loss: 282.7758
# ====> Epoch: 63 Average loss: 284.4862
# ====> Test set loss: 283.6439
# ====> Epoch: 64 Average loss: 284.7420
# ====> Test set loss: 279.9837
# ====> Epoch: 65 Average loss: 283.3597
# ====> Test set loss: 280.3642
# ====> Epoch: 66 Average loss: 283.7821
# ====> Test set loss: 279.0801
# ====> Epoch: 67 Average loss: 284.1541
# ====> Test set loss: 279.9392
# ====> Epoch: 68 Average loss: 283.2169
# ====> Test set loss: 282.2197
# ====> Epoch: 69 Average loss: 283.6748
# ====> Test set loss: 283.5291
# ====> Epoch: 70 Average loss: 283.1787
# ====> Test set loss: 284.3011
# ====> Epoch: 71 Average loss: 282.7653
# ====> Test set loss: 279.3456
# ====> Epoch: 72 Average loss: 281.5916
# ====> Test set loss: 284.5820
# ====> Epoch: 73 Average loss: 283.0170
# ====> Test set loss: 281.8165
# ====> Epoch: 74 Average loss: 282.3913
# ====> Test set loss: 276.7868
# ====> Epoch: 75 Average loss: 282.0098
# ====> Test set loss: 284.5524
# ====> Epoch: 76 Average loss: 281.7953
# ====> Test set loss: 280.9750
# ====> Epoch: 77 Average loss: 281.3381
# ====> Test set loss: 277.3116
# ====> Epoch: 78 Average loss: 281.9344
# ====> Test set loss: 281.2082
# ====> Epoch: 79 Average loss: 282.4137
# ====> Test set loss: 278.4028
# ====> Epoch: 80 Average loss: 281.2459
# ====> Test set loss: 284.4315
# ====> Epoch: 81 Average loss: 280.7207
# ====> Test set loss: 281.8894
# ====> Epoch: 82 Average loss: 281.3896
# ====> Test set loss: 279.2560
# ====> Epoch: 83 Average loss: 280.1258
# ====> Test set loss: 278.7119
# ====> Epoch: 84 Average loss: 280.9028
# ====> Test set loss: 277.1548
# ====> Epoch: 85 Average loss: 281.2554
# ====> Test set loss: 277.0448
# ====> Epoch: 86 Average loss: 280.5609
# ====> Test set loss: 280.7600
# ====> Epoch: 87 Average loss: 280.5958
# ====> Test set loss: 281.0431
# ====> Epoch: 88 Average loss: 280.1600
# ====> Test set loss: 280.2614
# ====> Epoch: 89 Average loss: 280.5298
# ====> Test set loss: 277.7895
# ====> Epoch: 90 Average loss: 280.7016
# ====> Test set loss: 276.3086
# ====> Epoch: 91 Average loss: 278.2515
# ====> Test set loss: 279.6111
# ====> Epoch: 92 Average loss: 279.6912
# ====> Test set loss: 288.2935
# ====> Epoch: 93 Average loss: 279.6943
# ====> Test set loss: 282.1053
# ====> Epoch: 94 Average loss: 279.1252
# ====> Test set loss: 278.4334
# ====> Epoch: 95 Average loss: 280.0057
# ====> Test set loss: 279.2602
# ====> Epoch: 96 Average loss: 279.0619
# ====> Test set loss: 278.3858
# ====> Epoch: 97 Average loss: 280.7854
# ====> Test set loss: 279.6273
# ====> Epoch: 98 Average loss: 279.5000
# ====> Test set loss: 277.2063
# ====> Epoch: 99 Average loss: 279.6684
# ====> Test set loss: 276.2145
# ====> Epoch: 100 Average loss: 280.3739
# ====> Test set loss: 276.7817
# ====> Epoch: 101 Average loss: 279.8688
# ====> Test set loss: 277.2992
# ====> Epoch: 102 Average loss: 280.4048
# ====> Test set loss: 275.4102
# ====> Epoch: 103 Average loss: 280.7112
# ====> Test set loss: 277.1619
# ====> Epoch: 104 Average loss: 280.3727
# ====> Test set loss: 279.9939
# ====> Epoch: 105 Average loss: 280.0922
# ====> Test set loss: 285.0026
# ====> Epoch: 106 Average loss: 279.1673
# ====> Test set loss: 277.4719
# ====> Epoch: 107 Average loss: 278.9223
# ====> Test set loss: 279.2885
# ====> Epoch: 108 Average loss: 279.7028
# ====> Test set loss: 275.6507
# ====> Epoch: 109 Average loss: 278.5895
# ====> Test set loss: 277.3328
# ====> Epoch: 110 Average loss: 279.6280
# ====> Test set loss: 279.8026
# ====> Epoch: 111 Average loss: 278.7886
# ====> Test set loss: 276.1338
# ====> Epoch: 112 Average loss: 279.2418
# ====> Test set loss: 273.5394
# ====> Epoch: 113 Average loss: 277.3524
# ====> Test set loss: 275.8577
# ====> Epoch: 114 Average loss: 278.7970
# ====> Test set loss: 276.9690
# ====> Epoch: 115 Average loss: 279.2929
# ====> Test set loss: 276.5354
# ====> Epoch: 116 Average loss: 279.1513
# ====> Test set loss: 279.0591
# ====> Epoch: 117 Average loss: 278.5253
# ====> Test set loss: 277.4593
# ====> Epoch: 118 Average loss: 278.8682
# ====> Test set loss: 279.3853
# ====> Epoch: 119 Average loss: 277.8447
# ====> Test set loss: 275.5261
# ====> Epoch: 120 Average loss: 278.0344
# ====> Test set loss: 279.3055
# ====> Epoch: 121 Average loss: 278.3775
# ====> Test set loss: 279.9044
# ====> Epoch: 122 Average loss: 278.2179
# ====> Test set loss: 276.0143
# ====> Epoch: 123 Average loss: 279.9389
# ====> Test set loss: 274.5525
# ====> Epoch: 124 Average loss: 278.9745
# ====> Test set loss: 277.3652
# ====> Epoch: 125 Average loss: 278.0985
# ====> Test set loss: 280.1163
# ====> Epoch: 126 Average loss: 277.6431
# ====> Test set loss: 276.0346
# ====> Epoch: 127 Average loss: 278.7676
# ====> Test set loss: 279.3654
# ====> Epoch: 128 Average loss: 279.3884
# ====> Test set loss: 277.0567
# ====> Epoch: 129 Average loss: 276.9377
# ====> Test set loss: 281.2957
# ====> Epoch: 130 Average loss: 277.7361
# ====> Test set loss: 276.9261
# ====> Epoch: 131 Average loss: 277.9010
# ====> Test set loss: 277.5570
# ====> Epoch: 132 Average loss: 277.8075
# ====> Test set loss: 275.2881
# ====> Epoch: 133 Average loss: 276.9998
# ====> Test set loss: 281.0168
# ====> Epoch: 134 Average loss: 276.9746
# ====> Test set loss: 271.6830
# ====> Epoch: 135 Average loss: 277.4726
# ====> Test set loss: 277.4754
# ====> Epoch: 136 Average loss: 276.4619
# ====> Test set loss: 276.8427
# ====> Epoch: 137 Average loss: 276.9586
# ====> Test set loss: 273.3048
# ====> Epoch: 138 Average loss: 277.6374
# ====> Test set loss: 275.1374
# ====> Epoch: 139 Average loss: 277.2045
# ====> Test set loss: 272.1506
# ====> Epoch: 140 Average loss: 277.3430
# ====> Test set loss: 279.8585
# ====> Epoch: 141 Average loss: 276.7278
# ====> Test set loss: 277.6278
# ====> Epoch: 142 Average loss: 275.5884
# ====> Test set loss: 276.4101
# ====> Epoch: 143 Average loss: 276.1032
# ====> Test set loss: 272.5952
# ====> Epoch: 144 Average loss: 277.3912
# ====> Test set loss: 274.5081
# ====> Epoch: 145 Average loss: 277.6502
# ====> Test set loss: 281.1895
# ====> Epoch: 146 Average loss: 279.3407
# ====> Test set loss: 276.9200
# ====> Epoch: 147 Average loss: 278.0269
# ====> Test set loss: 274.0759
# ====> Epoch: 148 Average loss: 277.7448
# ====> Test set loss: 272.4103
# ====> Epoch: 149 Average loss: 277.7476
# ====> Test set loss: 277.0921
# ====> Epoch: 150 Average loss: 276.3291
# ====> Test set loss: 275.7246
# ====> Epoch: 151 Average loss: 276.9021
# ====> Test set loss: 275.1849
# ====> Epoch: 152 Average loss: 277.2591
# ====> Test set loss: 272.0362
# ====> Epoch: 153 Average loss: 276.6134
# ====> Test set loss: 273.9422
# ====> Epoch: 154 Average loss: 276.9975
# ====> Test set loss: 277.6589
# ====> Epoch: 155 Average loss: 275.6450
# ====> Test set loss: 271.8461
# ====> Epoch: 156 Average loss: 275.7243
# ====> Test set loss: 273.7420
# ====> Epoch: 157 Average loss: 276.1591
# ====> Test set loss: 273.9555
# ====> Epoch: 158 Average loss: 275.5715
# ====> Test set loss: 275.9344
# ====> Epoch: 159 Average loss: 274.7029
# ====> Test set loss: 276.2493
# ====> Epoch: 160 Average loss: 275.7711
# ====> Test set loss: 273.5292
# ====> Epoch: 161 Average loss: 275.2597
# ====> Test set loss: 274.2226
# ====> Epoch: 162 Average loss: 275.8005
# ====> Test set loss: 275.2809
# ====> Epoch: 163 Average loss: 275.4202
# ====> Test set loss: 273.4567
# ====> Epoch: 164 Average loss: 275.8014
# ====> Test set loss: 272.2559
# ====> Epoch: 165 Average loss: 276.3161
# ====> Test set loss: 277.3602
# ====> Epoch: 166 Average loss: 276.2835
# ====> Test set loss: 273.1197
# ====> Epoch: 167 Average loss: 275.3521
# ====> Test set loss: 272.5771
# ====> Epoch: 168 Average loss: 276.9635
# ====> Test set loss: 273.2946
# ====> Epoch: 169 Average loss: 274.8381
# ====> Test set loss: 271.6304
# ====> Epoch: 170 Average loss: 275.4851
# ====> Test set loss: 273.7551
# ====> Epoch: 171 Average loss: 274.5870
# ====> Test set loss: 277.4207
# ====> Epoch: 172 Average loss: 274.0948
# ====> Test set loss: 272.1710
# ====> Epoch: 173 Average loss: 274.2249
# ====> Test set loss: 272.5128
# ====> Epoch: 174 Average loss: 275.3867
# ====> Test set loss: 272.5568
# ====> Epoch: 175 Average loss: 274.3893
# ====> Test set loss: 273.5954
# ====> Epoch: 176 Average loss: 274.3362
# ====> Test set loss: 274.1192
# ====> Epoch: 177 Average loss: 273.8967
# ====> Test set loss: 271.9823
# ====> Epoch: 178 Average loss: 273.5596
# ====> Test set loss: 274.2770
# ====> Epoch: 179 Average loss: 274.0793
# ====> Test set loss: 274.1821
# ====> Epoch: 180 Average loss: 274.2650
# ====> Test set loss: 270.8793
# ====> Epoch: 181 Average loss: 274.5834
# ====> Test set loss: 272.4312
# ====> Epoch: 182 Average loss: 275.5267
# ====> Test set loss: 270.6468
# ====> Epoch: 183 Average loss: 272.9814
# ====> Test set loss: 272.6688
# ====> Epoch: 184 Average loss: 272.7964
# ====> Test set loss: 277.7882
# ====> Epoch: 185 Average loss: 273.9184
# ====> Test set loss: 272.4108
# ====> Epoch: 186 Average loss: 273.2807
# ====> Test set loss: 274.3209
# ====> Epoch: 187 Average loss: 273.8384
# ====> Test set loss: 271.3847
# ====> Epoch: 188 Average loss: 273.5888
# ====> Test set loss: 274.6644
# ====> Epoch: 189 Average loss: 272.9292
# ====> Test set loss: 272.7716
# ====> Epoch: 190 Average loss: 274.7283
# ====> Test set loss: 271.4651
# ====> Epoch: 191 Average loss: 272.8511
# ====> Test set loss: 272.3520
# ====> Epoch: 192 Average loss: 273.0261
# ====> Test set loss: 269.2207
# ====> Epoch: 193 Average loss: 273.0838
# ====> Test set loss: 273.2348
# ====> Epoch: 194 Average loss: 272.1033
# ====> Test set loss: 272.7460
# ====> Epoch: 195 Average loss: 273.7573
# ====> Test set loss: 271.5887
# ====> Epoch: 196 Average loss: 273.1705
# ====> Test set loss: 271.1346
# ====> Epoch: 197 Average loss: 273.0382
# ====> Test set loss: 273.1916
# ====> Epoch: 198 Average loss: 272.8087
# ====> Test set loss: 271.6491
# ====> Epoch: 199 Average loss: 272.7172
# ====> Test set loss: 275.9956
# ====> Epoch: 200 Average loss: 272.5703
# ====> Test set loss: 270.0502
# ====> Epoch: 201 Average loss: 272.3137
# ====> Test set loss: 272.6811
# ====> Epoch: 202 Average loss: 274.2638
# ====> Test set loss: 270.1366
# ====> Epoch: 203 Average loss: 273.3017
# ====> Test set loss: 275.7200
# ====> Epoch: 204 Average loss: 273.1075
# ====> Test set loss: 270.5934
# ====> Epoch: 205 Average loss: 273.7895
# ====> Test set loss: 273.6616
# ====> Epoch: 206 Average loss: 274.5150
# ====> Test set loss: 272.6242
# ====> Epoch: 207 Average loss: 273.4782
# ====> Test set loss: 271.5339
# ====> Epoch: 208 Average loss: 272.1494
# ====> Test set loss: 275.3315
# ====> Epoch: 209 Average loss: 273.4273
# ====> Test set loss: 272.1441
# ====> Epoch: 210 Average loss: 272.5016
# ====> Test set loss: 273.7474
# ====> Epoch: 211 Average loss: 272.9866
# ====> Test set loss: 271.8337
# ====> Epoch: 212 Average loss: 273.9702
# ====> Test set loss: 269.4313
# ====> Epoch: 213 Average loss: 272.7926
# ====> Test set loss: 274.8967
# ====> Epoch: 214 Average loss: 272.4376
# ====> Test set loss: 268.8591
# ====> Epoch: 215 Average loss: 272.4779
# ====> Test set loss: 268.2726
# ====> Epoch: 216 Average loss: 273.4135
# ====> Test set loss: 271.5002
# ====> Epoch: 217 Average loss: 273.0417
# ====> Test set loss: 274.0183
# ====> Epoch: 218 Average loss: 273.4730
# ====> Test set loss: 271.1340
# ====> Epoch: 219 Average loss: 271.6670
# ====> Test set loss: 270.8789
# ====> Epoch: 220 Average loss: 273.6435
# ====> Test set loss: 280.5600
# ====> Epoch: 221 Average loss: 272.8176
# ====> Test set loss: 271.0428
# ====> Epoch: 222 Average loss: 271.6563
# ====> Test set loss: 271.0916
# ====> Epoch: 223 Average loss: 273.4617
# ====> Test set loss: 269.4566
# ====> Epoch: 224 Average loss: 273.0931
# ====> Test set loss: 270.3842
# ====> Epoch: 225 Average loss: 271.8976
# ====> Test set loss: 274.9289
# ====> Epoch: 226 Average loss: 272.3792
# ====> Test set loss: 268.3544
# ====> Epoch: 227 Average loss: 273.0743
# ====> Test set loss: 272.3374
# ====> Epoch: 228 Average loss: 272.5538
# ====> Test set loss: 269.9402
# ====> Epoch: 229 Average loss: 273.0315
# ====> Test set loss: 266.9591
# ====> Epoch: 230 Average loss: 272.6009
# ====> Test set loss: 271.6064
# ====> Epoch: 231 Average loss: 271.7478
# ====> Test set loss: 270.6948
# ====> Epoch: 232 Average loss: 272.0627
# ====> Test set loss: 272.3532
# ====> Epoch: 233 Average loss: 273.9711
# ====> Test set loss: 272.2867
# ====> Epoch: 234 Average loss: 271.7629
# ====> Test set loss: 277.5032
# ====> Epoch: 235 Average loss: 271.5057
# ====> Test set loss: 270.5153
# ====> Epoch: 236 Average loss: 273.4730
# ====> Test set loss: 268.9009
# ====> Epoch: 237 Average loss: 272.6471
# ====> Test set loss: 270.6489
# ====> Epoch: 238 Average loss: 272.6558
# ====> Test set loss: 267.9927
# ====> Epoch: 239 Average loss: 271.7702
# ====> Test set loss: 267.9834
# ====> Epoch: 240 Average loss: 271.1456
# ====> Test set loss: 271.8078
# ====> Epoch: 241 Average loss: 271.4132
# ====> Test set loss: 270.2854
# ====> Epoch: 242 Average loss: 273.0032
# ====> Test set loss: 269.8652
# ====> Epoch: 243 Average loss: 270.9449
# ====> Test set loss: 270.0155
# ====> Epoch: 244 Average loss: 271.4136
# ====> Test set loss: 270.9526
# ====> Epoch: 245 Average loss: 270.5452
# ====> Test set loss: 267.3130
# ====> Epoch: 246 Average loss: 273.2702
# ====> Test set loss: 268.3810
# ====> Epoch: 247 Average loss: 272.2554
# ====> Test set loss: 271.7078
# ====> Epoch: 248 Average loss: 271.6800
# ====> Test set loss: 268.0331
# ====> Epoch: 249 Average loss: 271.9274
# ====> Test set loss: 271.5595
# ====> Epoch: 250 Average loss: 272.2341
# ====> Test set loss: 268.1223
# ====> Epoch: 251 Average loss: 271.3410
# ====> Test set loss: 269.3292
# ====> Epoch: 252 Average loss: 270.9913
# ====> Test set loss: 271.4120
# ====> Epoch: 253 Average loss: 271.0844
# ====> Test set loss: 270.2808
# ====> Epoch: 254 Average loss: 272.8469
# ====> Test set loss: 270.6700
# ====> Epoch: 255 Average loss: 271.9846
# ====> Test set loss: 274.0309
# ====> Epoch: 256 Average loss: 272.2230
# ====> Test set loss: 273.1674
# ====> Epoch: 257 Average loss: 273.1405
# ====> Test set loss: 270.6207
# ====> Epoch: 258 Average loss: 271.1552
# ====> Test set loss: 270.7368
# ====> Epoch: 259 Average loss: 271.0768
# ====> Test set loss: 271.4172
# ====> Epoch: 260 Average loss: 272.3587
# ====> Test set loss: 270.7553
# ====> Epoch: 261 Average loss: 270.9522
# ====> Test set loss: 268.0932
# ====> Epoch: 262 Average loss: 271.1646
# ====> Test set loss: 269.4988
# ====> Epoch: 263 Average loss: 271.6662
# ====> Test set loss: 271.4888
# ====> Epoch: 264 Average loss: 272.0095
# ====> Test set loss: 271.2966
# ====> Epoch: 265 Average loss: 270.7667
# ====> Test set loss: 269.7956
# ====> Epoch: 266 Average loss: 272.6121
# ====> Test set loss: 270.2862
# ====> Epoch: 267 Average loss: 270.9918
# ====> Test set loss: 271.2284
# ====> Epoch: 268 Average loss: 272.1927
# ====> Test set loss: 268.3347
# ====> Epoch: 269 Average loss: 272.1828
# ====> Test set loss: 267.2497
# ====> Epoch: 270 Average loss: 271.4028
# ====> Test set loss: 271.7608
# ====> Epoch: 271 Average loss: 271.7071
# ====> Test set loss: 273.3451
# ====> Epoch: 272 Average loss: 270.7777
# ====> Test set loss: 272.6700
# ====> Epoch: 273 Average loss: 272.2326
# ====> Test set loss: 270.7231
# ====> Epoch: 274 Average loss: 270.7836
# ====> Test set loss: 271.3785
# ====> Epoch: 275 Average loss: 272.2105
# ====> Test set loss: 268.6833
# ====> Epoch: 276 Average loss: 270.6849
# ====> Test set loss: 269.5389
# ====> Epoch: 277 Average loss: 272.1728
# ====> Test set loss: 273.1836
# ====> Epoch: 278 Average loss: 270.9615
# ====> Test set loss: 271.7850
# ====> Epoch: 279 Average loss: 273.1200
# ====> Test set loss: 267.7039
# ====> Epoch: 280 Average loss: 270.9392
# ====> Test set loss: 272.0168
# ====> Epoch: 281 Average loss: 271.9730
# ====> Test set loss: 270.6164
# ====> Epoch: 282 Average loss: 270.7763
# ====> Test set loss: 274.0399
# ====> Epoch: 283 Average loss: 271.0981
# ====> Test set loss: 269.8704
# ====> Epoch: 284 Average loss: 271.8488
# ====> Test set loss: 269.8090
# ====> Epoch: 285 Average loss: 272.2481
# ====> Test set loss: 265.6306
# ====> Epoch: 286 Average loss: 269.7768
# ====> Test set loss: 271.8208
# ====> Epoch: 287 Average loss: 271.4456
# ====> Test set loss: 269.1771
# ====> Epoch: 288 Average loss: 271.5304
# ====> Test set loss: 269.2381
# ====> Epoch: 289 Average loss: 269.7979
# ====> Test set loss: 272.7743
# ====> Epoch: 290 Average loss: 272.1308
# ====> Test set loss: 270.3469
# ====> Epoch: 291 Average loss: 271.5684
# ====> Test set loss: 268.6078
# ====> Epoch: 292 Average loss: 271.7128
# ====> Test set loss: 272.7355
# ====> Epoch: 293 Average loss: 270.1897
# ====> Test set loss: 268.0991
# ====> Epoch: 294 Average loss: 270.5695
# ====> Test set loss: 269.5664
# ====> Epoch: 295 Average loss: 270.5964
# ====> Test set loss: 270.1088
# ====> Epoch: 296 Average loss: 271.2650
# ====> Test set loss: 267.3464
# ====> Epoch: 297 Average loss: 269.3419
# ====> Test set loss: 268.3433
# ====> Epoch: 298 Average loss: 270.3371
# ====> Test set loss: 269.3680
# ====> Epoch: 299 Average loss: 268.9736
# ====> Test set loss: 268.8833
# ====> Epoch: 300 Average loss: 271.1906
# ====> Test set loss: 270.4104
# ====> Epoch: 301 Average loss: 270.5301
# ====> Test set loss: 268.3504
# ====> Epoch: 302 Average loss: 271.9412
# ====> Test set loss: 267.1379
# ====> Epoch: 303 Average loss: 270.0600
# ====> Test set loss: 271.4315
# ====> Epoch: 304 Average loss: 269.3335
# ====> Test set loss: 271.5559
# ====> Epoch: 305 Average loss: 271.2089
# ====> Test set loss: 267.7682
# ====> Epoch: 306 Average loss: 270.0235
# ====> Test set loss: 267.6566
# ====> Epoch: 307 Average loss: 269.3327
# ====> Test set loss: 273.6979
# ====> Epoch: 308 Average loss: 270.1521
# ====> Test set loss: 269.2336
# ====> Epoch: 309 Average loss: 271.5699
# ====> Test set loss: 268.1590
# ====> Epoch: 310 Average loss: 271.3515
# ====> Test set loss: 271.7383
# ====> Epoch: 311 Average loss: 271.5041
# ====> Test set loss: 270.4495
# ====> Epoch: 312 Average loss: 271.4088
# ====> Test set loss: 271.3287
# ====> Epoch: 313 Average loss: 271.3301
# ====> Test set loss: 269.0444
# ====> Epoch: 314 Average loss: 270.1648
# ====> Test set loss: 270.3264
# ====> Epoch: 315 Average loss: 270.9139
# ====> Test set loss: 269.5885
# ====> Epoch: 316 Average loss: 271.3536
# ====> Test set loss: 270.5372
# ====> Epoch: 317 Average loss: 272.0211
# ====> Test set loss: 267.5400
# ====> Epoch: 318 Average loss: 270.0571
# ====> Test set loss: 268.0793
# ====> Epoch: 319 Average loss: 269.9106
# ====> Test set loss: 268.9326
# ====> Epoch: 320 Average loss: 270.5035
# ====> Test set loss: 266.9800
# ====> Epoch: 321 Average loss: 273.3111
# ====> Test set loss: 269.0708
# ====> Epoch: 322 Average loss: 272.8556
# ====> Test set loss: 268.7202
# ====> Epoch: 323 Average loss: 271.4513
# ====> Test set loss: 268.8499
# ====> Epoch: 324 Average loss: 270.5696
# ====> Test set loss: 269.7487
# ====> Epoch: 325 Average loss: 270.1317
# ====> Test set loss: 269.2396
# ====> Epoch: 326 Average loss: 271.1941
# ====> Test set loss: 269.3370
# ====> Epoch: 327 Average loss: 270.4662
# ====> Test set loss: 269.8212
# ====> Epoch: 328 Average loss: 269.7080
# ====> Test set loss: 272.2053
# ====> Epoch: 329 Average loss: 269.7849
# ====> Test set loss: 268.3612
# ====> Epoch: 330 Average loss: 269.2076
# ====> Test set loss: 267.8149
# ====> Epoch: 331 Average loss: 270.4619
# ====> Test set loss: 269.7431
# ====> Epoch: 332 Average loss: 270.4931
# ====> Test set loss: 270.0758
# ====> Epoch: 333 Average loss: 269.9886
# ====> Test set loss: 270.7339
# ====> Epoch: 334 Average loss: 271.7492
# ====> Test set loss: 270.4553
# ====> Epoch: 335 Average loss: 270.8864
# ====> Test set loss: 268.6942
# ====> Epoch: 336 Average loss: 270.0577
# ====> Test set loss: 269.6801
# ====> Epoch: 337 Average loss: 270.8549
# ====> Test set loss: 269.5938
# ====> Epoch: 338 Average loss: 271.2472
# ====> Test set loss: 269.0078
# ====> Epoch: 339 Average loss: 269.6205
# ====> Test set loss: 266.1680
# ====> Epoch: 340 Average loss: 270.3548
# ====> Test set loss: 267.9492
# ====> Epoch: 341 Average loss: 270.6119
# ====> Test set loss: 270.6704
# ====> Epoch: 342 Average loss: 270.0630
# ====> Test set loss: 271.2942
# ====> Epoch: 343 Average loss: 269.3394
# ====> Test set loss: 266.5620
# ====> Epoch: 344 Average loss: 269.9619
# ====> Test set loss: 269.2513
# ====> Epoch: 345 Average loss: 271.3319
# ====> Test set loss: 270.3813
# ====> Epoch: 346 Average loss: 269.8512
# ====> Test set loss: 269.3675
# ====> Epoch: 347 Average loss: 270.9915
# ====> Test set loss: 270.4727
# ====> Epoch: 348 Average loss: 269.9965
# ====> Test set loss: 271.0350
# ====> Epoch: 349 Average loss: 269.8349
# ====> Test set loss: 270.1508
# ====> Epoch: 350 Average loss: 271.3110
# ====> Test set loss: 271.3659
# ====> Epoch: 351 Average loss: 270.2709
# ====> Test set loss: 267.7613
# ====> Epoch: 352 Average loss: 270.1514
# ====> Test set loss: 268.0336
# ====> Epoch: 353 Average loss: 270.0806
# ====> Test set loss: 266.7779
# ====> Epoch: 354 Average loss: 271.0993
# ====> Test set loss: 271.6816
# ====> Epoch: 355 Average loss: 270.2244
# ====> Test set loss: 268.0384
# ====> Epoch: 356 Average loss: 270.3796
# ====> Test set loss: 272.3905
# ====> Epoch: 357 Average loss: 271.3975
# ====> Test set loss: 269.5072
# ====> Epoch: 358 Average loss: 269.3879
# ====> Test set loss: 272.4516
# ====> Epoch: 359 Average loss: 270.7958
# ====> Test set loss: 269.9385
# ====> Epoch: 360 Average loss: 270.0525
# ====> Test set loss: 272.6227
# ====> Epoch: 361 Average loss: 269.0616
# ====> Test set loss: 270.3591
# ====> Epoch: 362 Average loss: 270.5911
# ====> Test set loss: 266.8996
# ====> Epoch: 363 Average loss: 269.2459
# ====> Test set loss: 270.5761
# ====> Epoch: 364 Average loss: 269.5095
# ====> Test set loss: 270.8699
# ====> Epoch: 365 Average loss: 270.3110
# ====> Test set loss: 269.5664
# ====> Epoch: 366 Average loss: 269.4456
# ====> Test set loss: 269.1499
# ====> Epoch: 367 Average loss: 270.6520
# ====> Test set loss: 272.6172
# ====> Epoch: 368 Average loss: 269.4849
# ====> Test set loss: 274.9801
# ====> Epoch: 369 Average loss: 270.5046
# ====> Test set loss: 270.5732
# ====> Epoch: 370 Average loss: 270.6198
# ====> Test set loss: 267.6513
# ====> Epoch: 371 Average loss: 269.8926
# ====> Test set loss: 269.5160
# ====> Epoch: 372 Average loss: 269.3226
# ====> Test set loss: 268.2042
# ====> Epoch: 373 Average loss: 268.5659
# ====> Test set loss: 272.2978
# ====> Epoch: 374 Average loss: 269.0668
# ====> Test set loss: 271.1899
# ====> Epoch: 375 Average loss: 269.4209
# ====> Test set loss: 275.4052
# ====> Epoch: 376 Average loss: 270.4502
# ====> Test set loss: 268.7895
# ====> Epoch: 377 Average loss: 270.0472
# ====> Test set loss: 268.2616
# ====> Epoch: 378 Average loss: 270.0196
# ====> Test set loss: 270.1431
# ====> Epoch: 379 Average loss: 269.5596
# ====> Test set loss: 271.6857
# ====> Epoch: 380 Average loss: 269.7190
# ====> Test set loss: 270.2296
# ====> Epoch: 381 Average loss: 269.3632
# ====> Test set loss: 267.4300
# ====> Epoch: 382 Average loss: 269.9496
# ====> Test set loss: 269.8051
# ====> Epoch: 383 Average loss: 270.0181
# ====> Test set loss: 271.0872
# ====> Epoch: 384 Average loss: 269.7268
# ====> Test set loss: 268.7936
# ====> Epoch: 385 Average loss: 269.5428
# ====> Test set loss: 269.7585
# ====> Epoch: 386 Average loss: 270.1933
# ====> Test set loss: 272.6671
# ====> Epoch: 387 Average loss: 268.5092
# ====> Test set loss: 270.0973
# ====> Epoch: 388 Average loss: 270.2811
# ====> Test set loss: 267.6862
# ====> Epoch: 389 Average loss: 268.2796
# ====> Test set loss: 269.0030
# ====> Epoch: 390 Average loss: 271.0368
# ====> Test set loss: 267.0232
# ====> Epoch: 391 Average loss: 271.1802
# ====> Test set loss: 268.4845
# ====> Epoch: 392 Average loss: 269.2914
# ====> Test set loss: 267.9531
# ====> Epoch: 393 Average loss: 269.7089
# ====> Test set loss: 269.9594
# ====> Epoch: 394 Average loss: 270.4670
# ====> Test set loss: 271.4396
# ====> Epoch: 395 Average loss: 269.8941
# ====> Test set loss: 267.6013
# ====> Epoch: 396 Average loss: 268.9475
# ====> Test set loss: 267.8674
# ====> Epoch: 397 Average loss: 269.5149
# ====> Test set loss: 268.0920
# ====> Epoch: 398 Average loss: 270.7691
# ====> Test set loss: 268.9640
# ====> Epoch: 399 Average loss: 269.3437
# ====> Test set loss: 265.3523
# ====> Epoch: 400 Average loss: 269.0599
# ====> Test set loss: 267.0645

# %%
plt.plot(np.array(train_losses),'r')
plt.show()
plt.plot(np.array(test_losses),'b')
plt.show()

# %% [markdown]
# ### Sample from trained model

# %%
# Generate a sequence of 10 time steps
sampler_test = PeriodicSamp(1, obs_dim, np.cos, 1)
latent_test, obs_test = sampler_test.sample_all(10)
obs_test = np.transpose(obs_test, (1, 0, 2))
obs_test_pre = obs_test[0,:9,:]
obs_test_after = obs_test[0,1:,:]
print(obs_test_pre.shape)
print(obs_test_after.shape)

model.eval()
train_data = torch.Tensor(obs_test_pre).to(device)
train_data = train_data.reshape(1, 9, 50)
print(train_data.shape)

mu, logvar,_,_ = model.forward(train_data)
covar = torch.diag_embed(torch.exp(logvar))
std_obs = torch.distributions.MultivariateNormal(mu, covar)
obs_sample = std_obs.sample()
print(obs_sample.shape)
obs_sample = obs_sample.cpu().numpy()
# Out:
# (9, 50)
# (9, 50)
# torch.Size([1, 9, 50])
# torch.Size([1, 9, 50])

# %%
x1 = np.arange(1, 10)
for i in range(50):
  plt.plot(x1, obs_sample[0, :, i], marker = 'o', markersize = 4)
  plt.xlabel('Time')
  plt.ylabel('Magnitude')
  plt.title('Reconstructed Signal');
plt.show()

# %%
for i in range(50):
  plt.plot(x1, obs_test_after[:, i], marker = 'o', markersize = 4)
  plt.xlabel('Time')
  plt.ylabel('Magnitude')
  plt.title('True Signal');
plt.show()
